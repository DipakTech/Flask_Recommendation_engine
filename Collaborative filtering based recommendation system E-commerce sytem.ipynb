# %% [markdown]
# # Documentation for pymongo Installation and Usage in Cosine similarity recommendation

# %% [markdown]
# ## Introduction

# %% [markdown]
# `pymongo` is a Python library that provides tools and functionalities for working with MongoDB, a popular NoSQL database. This documentation will guide you through the process of installing `pymongo` and using it to interact with MongoDB databases.

# %% [markdown]
# ### Installation

# %% [markdown]
# To install `pymongo`, you can use the Python package manager
# `pip`. Follow the steps below:
#
# 1. Open a command prompt or terminal on your computer.
# 2. Run the following command:

# %%
# !pip install pymongo
# Out:
# Requirement already satisfied: pymongo in c:\users\user\anaconda3\lib\site-packages (4.3.3)
# Requirement already satisfied: dnspython<3.0.0,>=1.16.0 in c:\users\user\anaconda3\lib\site-packages (from pymongo) (2.3.0)

# %% [markdown]
# 3. Wait for the installation to complete. Once installed, you can now import and use `pymongo` in your Python projects.

# %% [markdown]
# ## Importing Required Libraries

# %% [markdown]
# Before using `pymongo`, you need to import some additional libraries: `pandas` and `numpy`. These libraries provide functionalities for working with data frames and arrays, which can be useful when manipulating MongoDB data.

# %%
import pymongo 
import pandas as pd 
import numpy as np

# %% [markdown]
# ### Connecting to MongoDB

# %% [markdown]
# To connect to a MongoDB database, you need to create an instance of the `MongoClient` class and pass the connection string as a parameter. The connection string contains information about the MongoDB server, such as the hostname, port, and authentication credentials.

# %%
client=pymongo.MongoClient("mongodb+srv://dipak:isJNvrJEVWg5im3q@cluster0.x4jjg.mongodb.net/test")

# %% [markdown]
# ## Accessing a Database and Collection

# %% [markdown]
# Once connected to the MongoDB server, you can access a specific database and collection using the [] operator on the client object.

# %%
db=client["sportShop"]
product=db.products

# %% [markdown]
# In the example above, we accessed the "sportShop" database and the "products" collection within that database.

# %% [markdown]
# ## Retrieving Documents from a Collection

# %% [markdown]
# To retrieve documents from a collection, you can use the `find` method on the collection object. The `find` method returns a cursor, which can be iterated to access the documents.

# %%
all_products=product.find({})
list_products=list(all_products)

# %% [markdown]
# The code above retrieves all documents from the "products" collection and converts them into a list.

# %% [markdown]
# # Creating a DataFrame from MongoDB Documents

# %% [markdown]
# To work with the retrieved MongoDB documents as a tabular data structure, you can create a DataFrame using the `pandas` library.

# %%
df=pd.DataFrame(list_products)
df.head()
# Out:
#                         _id    rating  numReviews   price  countInStock  \
# 0  63e7989616745843a0c18b7c  3.750000           8   89.99             3
# 1  63e7989616745843a0c18b88  3.600000           5  399.99            20
# 2  63e7989616745843a0c18b7f  3.500000           6  399.99            10
# 3  63e7989616745843a0c18b8a  1.857143           7  199.99            30
# 4  63e7989616745843a0c18b87  2.800000           5  799.99            10
#
#                                              name                      image  \
# 0           Airpods Wireless Bluetooth Headphones        /images/airpods.jpg
# 1                  Canon EOS Rebel T7 DSLR Camera     /images/6323758_bd.jpg
# 2            Sony Playstation 4 Pro White Version    /images/playstation.jpg
# 3  Beats by Dre Powerbeats Pro Wireless Earphones   /images/downloadbead.jpg
# 4                                  Apple iPad Pro  /images/downloadapple.jpg
#
#                                          description         brand  \
# 0  Bluetooth technology lets you connect it with ...         Apple
# 1  Capture stunning photographs with the Canon EO...         Canon
# 2  The ultimate home entertainment center starts ...          Sony
# 3  Get in the zone with the Beats by Dre Powerbea...  Beats by Dre
# 4  Get work done and stay connected on the go wit...         Apple
#
#       category                      user  \
# 0  Electronics  63e7989616745843a0c18b65
# 1  Electronics  63e7989616745843a0c18b65
# 2  Electronics  63e7989616745843a0c18b65
# 3  Electronics  63e7989616745843a0c18b65
# 4  Electronics  63e7989616745843a0c18b65
#
#                                              reviews  __v  \
# 0  [{'_id': 63e799d03229b9401471c95f, 'name': 'sa...    8
# 1  [{'_id': 63eb90ec8e2fe542a489f9d9, 'name': 're...    5
# 2  [{'_id': 63e79a2b3229b9401471c961, 'name': 'sa...    6
# 3  [{'_id': 63eb90dc8e2fe542a489f9d8, 'name': 're...    7
# 4  [{'_id': 63e79aaa3229b9401471c964, 'name': 'ra...    5
#
#                 createdAt               updatedAt
# 0 2023-02-11 13:31:02.924 2023-05-04 11:37:57.943
# 1 2023-02-11 13:31:02.926 2023-05-08 21:44:52.134
# 2 2023-02-11 13:31:02.925 2023-05-08 22:35:35.673
# 3 2023-02-11 13:31:02.927 2023-04-27 12:10:38.950
# 4 2023-02-11 13:31:02.926 2023-04-27 12:02:50.360

# %% [markdown]
# The code above creates a DataFrame `df` from the list of MongoDB documents and displays the first few rows using the head method.

# %% [markdown]
# ## Data Manipulation and Analysis

# %%
df_list = []
for item in list_products:
    for sub_item in item['reviews']:
        df_list.append({'rating': sub_item['rating'],"product_id":item["_id"],'user_id': sub_item['user'],'product':item['name'],'image':item['image'],'price':item['price'] })
df = pd.DataFrame(df_list)
print(df)
# Out:
#      rating                product_id                   user_id  \
# 0         5  63e7989616745843a0c18b7c  63e7989616745843a0c18b7b
# 1         5  63e7989616745843a0c18b7c  63e7989616745843a0c18b68
# 2         4  63e7989616745843a0c18b7c  63e7989616745843a0c18b77
# 3         4  63e7989616745843a0c18b7c  63e7989616745843a0c18b75
# 4         5  63e7989616745843a0c18b7c  63e7989616745843a0c18b66
# ..      ...                       ...                       ...
# 209       4  6459659e2bf0540030b42b0c  64598b04138df50030b79610
# 210       3  6459659e2bf0540030b42b0c  644a5f6a4d690900314fa7a7
# 211       4  645965e82bf0540030b42b18  64596d2ae640040030448085
# 212       2  645965e82bf0540030b42b18  645978e5e640040030448235
# 213       5  645965e82bf0540030b42b18  64598b04138df50030b79610
#
#                                                product  \
# 0                Airpods Wireless Bluetooth Headphones
# 1                Airpods Wireless Bluetooth Headphones
# 2                Airpods Wireless Bluetooth Headphones
# 3                Airpods Wireless Bluetooth Headphones
# 4                Airpods Wireless Bluetooth Headphones
# ..                                                 ...
# 209  Nintendo Neon Purple/ Neon Orange Joy-Con (L-R...
# 210  Nintendo Neon Purple/ Neon Orange Joy-Con (L-R...
# 211  PowerA Enhanced Wireless Controller for Ninten...
# 212  PowerA Enhanced Wireless Controller for Ninten...
# 213  PowerA Enhanced Wireless Controller for Ninten...
#
#                                                  image  price
# 0                                  /images/airpods.jpg  89.99
# 1                                  /images/airpods.jpg  89.99
# 2                                  /images/airpods.jpg  89.99
# 3                                  /images/airpods.jpg  89.99
# 4                                  /images/airpods.jpg  89.99
# ..                                                 ...    ...
# 209  https://m.media-amazon.com/images/I/6197HqTcMi...   9.99
# 210  https://m.media-amazon.com/images/I/6197HqTcMi...   9.99
# 211  https://m.media-amazon.com/images/I/81BnaX3m1q...  19.99
# 212  https://m.media-amazon.com/images/I/81BnaX3m1q...  19.99
# 213  https://m.media-amazon.com/images/I/81BnaX3m1q...  19.99
#
# [214 rows x 6 columns]

# %% [markdown]
# ## Data Manipulation and Analysis

# %% [markdown]
# Once you have the DataFrame, you can perform various data manipulation and analysis tasks using pandas and numpy libraries. The example below demonstrates how to create a user rating pivot table and fill missing values.

# %%
userRating=df.pivot_table(index=["product"],columns=['user_id'],values='rating')
userRating.head()
# Out:
# user_id                                             63e7989616745843a0c18b65  \
# product
# AXE MEMORY Superb 512GB USB 3.1 SuperSpeed Flas...                       NaN
# Airpods Wireless Bluetooth Headphones                                    NaN
# Alfa Long-Range Dual-Band AC1200 Wireless USB 3...                       NaN
# Amazon Echo Dot 3rd Generation                                           NaN
# Apple 20W USB-C Power Adapter - iPhone Charger ...                       NaN
#
# user_id                                             63e7989616745843a0c18b66  \
# product
# AXE MEMORY Superb 512GB USB 3.1 SuperSpeed Flas...                       NaN
# Airpods Wireless Bluetooth Headphones                                    5.0
# Alfa Long-Range Dual-Band AC1200 Wireless USB 3...                       NaN
# Amazon Echo Dot 3rd Generation                                           NaN
# Apple 20W USB-C Power Adapter - iPhone Charger ...                       NaN
#
# user_id                                             63e7989616745843a0c18b68  \
# product
# AXE MEMORY Superb 512GB USB 3.1 SuperSpeed Flas...                       NaN
# Airpods Wireless Bluetooth Headphones                                    5.0
# Alfa Long-Range Dual-Band AC1200 Wireless USB 3...                       NaN
# Amazon Echo Dot 3rd Generation                                           NaN
# Apple 20W USB-C Power Adapter - iPhone Charger ...                       NaN
#
# user_id                                             63e7989616745843a0c18b69  \
# product
# AXE MEMORY Superb 512GB USB 3.1 SuperSpeed Flas...                       NaN
# Airpods Wireless Bluetooth Headphones                                    NaN
# Alfa Long-Range Dual-Band AC1200 Wireless USB 3...                       NaN
# Amazon Echo Dot 3rd Generation                                           NaN
# Apple 20W USB-C Power Adapter - iPhone Charger ...                       NaN
#
# user_id                                             63e7989616745843a0c18b6a  \
# product
# AXE MEMORY Superb 512GB USB 3.1 SuperSpeed Flas...                       NaN
# Airpods Wireless Bluetooth Headphones                                    NaN
# Alfa Long-Range Dual-Band AC1200 Wireless USB 3...                       NaN
# Amazon Echo Dot 3rd Generation                                           NaN
# Apple 20W USB-C Power Adapter - iPhone Charger ...                       NaN
#
# user_id                                             63e7989616745843a0c18b73  \
# product
# AXE MEMORY Superb 512GB USB 3.1 SuperSpeed Flas...                       NaN
# Airpods Wireless Bluetooth Headphones                                    NaN
# Alfa Long-Range Dual-Band AC1200 Wireless USB 3...                       NaN
# Amazon Echo Dot 3rd Generation                                           NaN
# Apple 20W USB-C Power Adapter - iPhone Charger ...                       NaN
#
# user_id                                             63e7989616745843a0c18b75  \
# product
# AXE MEMORY Superb 512GB USB 3.1 SuperSpeed Flas...                       NaN
# Airpods Wireless Bluetooth Headphones                                    4.0
# Alfa Long-Range Dual-Band AC1200 Wireless USB 3...                       NaN
# Amazon Echo Dot 3rd Generation                                           NaN
# Apple 20W USB-C Power Adapter - iPhone Charger ...                       NaN
#
# user_id                                             63e7989616745843a0c18b76  \
# product
# AXE MEMORY Superb 512GB USB 3.1 SuperSpeed Flas...                       NaN
# Airpods Wireless Bluetooth Headphones                                    NaN
# Alfa Long-Range Dual-Band AC1200 Wireless USB 3...                       NaN
# Amazon Echo Dot 3rd Generation                                           NaN
# Apple 20W USB-C Power Adapter - iPhone Charger ...                       NaN
#
# user_id                                             63e7989616745843a0c18b77  \
# product
# AXE MEMORY Superb 512GB USB 3.1 SuperSpeed Flas...                       NaN
# Airpods Wireless Bluetooth Headphones                                    4.0
# Alfa Long-Range Dual-Band AC1200 Wireless USB 3...                       NaN
# Amazon Echo Dot 3rd Generation                                           NaN
# Apple 20W USB-C Power Adapter - iPhone Charger ...                       NaN
#
# user_id                                             63e7989616745843a0c18b78  \
# product
# AXE MEMORY Superb 512GB USB 3.1 SuperSpeed Flas...                       NaN
# Airpods Wireless Bluetooth Headphones                                    NaN
# Alfa Long-Range Dual-Band AC1200 Wireless USB 3...                       NaN
# Amazon Echo Dot 3rd Generation                                           5.0
# Apple 20W USB-C Power Adapter - iPhone Charger ...                       NaN
#
# user_id                                             ...  \
# product                                             ...
# AXE MEMORY Superb 512GB USB 3.1 SuperSpeed Flas...  ...
# Airpods Wireless Bluetooth Headphones               ...
# Alfa Long-Range Dual-Band AC1200 Wireless USB 3...  ...
# Amazon Echo Dot 3rd Generation                      ...
# Apple 20W USB-C Power Adapter - iPhone Charger ...  ...
#
# user_id                                             644a5db34d690900314fa784  \
# product
# AXE MEMORY Superb 512GB USB 3.1 SuperSpeed Flas...                       NaN
# Airpods Wireless Bluetooth Headphones                                    NaN
# Alfa Long-Range Dual-Band AC1200 Wireless USB 3...                       NaN
# Amazon Echo Dot 3rd Generation                                           3.0
# Apple 20W USB-C Power Adapter - iPhone Charger ...                       NaN
#
# user_id                                             644a5f6a4d690900314fa7a7  \
# product
# AXE MEMORY Superb 512GB USB 3.1 SuperSpeed Flas...                       3.0
# Airpods Wireless Bluetooth Headphones                                    NaN
# Alfa Long-Range Dual-Band AC1200 Wireless USB 3...                       NaN
# Amazon Echo Dot 3rd Generation                                           NaN
# Apple 20W USB-C Power Adapter - iPhone Charger ...                       NaN
#
# user_id                                             644a61534d690900314fa7dd  \
# product
# AXE MEMORY Superb 512GB USB 3.1 SuperSpeed Flas...                       NaN
# Airpods Wireless Bluetooth Headphones                                    NaN
# Alfa Long-Range Dual-Band AC1200 Wireless USB 3...                       NaN
# Amazon Echo Dot 3rd Generation                                           NaN
# Apple 20W USB-C Power Adapter - iPhone Charger ...                       NaN
#
# user_id                                             644a63374d690900314fa808  \
# product
# AXE MEMORY Superb 512GB USB 3.1 SuperSpeed Flas...                       NaN
# Airpods Wireless Bluetooth Headphones                                    NaN
# Alfa Long-Range Dual-Band AC1200 Wireless USB 3...                       NaN
# Amazon Echo Dot 3rd Generation                                           NaN
# Apple 20W USB-C Power Adapter - iPhone Charger ...                       NaN
#
# user_id                                             644a65014d690900314fa839  \
# product
# AXE MEMORY Superb 512GB USB 3.1 SuperSpeed Flas...                       NaN
# Airpods Wireless Bluetooth Headphones                                    NaN
# Alfa Long-Range Dual-Band AC1200 Wireless USB 3...                       NaN
# Amazon Echo Dot 3rd Generation                                           1.0
# Apple 20W USB-C Power Adapter - iPhone Charger ...                       NaN
#
# user_id                                             6456380e9c6e6400328bd2e4  \
# product
# AXE MEMORY Superb 512GB USB 3.1 SuperSpeed Flas...                       NaN
# Airpods Wireless Bluetooth Headphones                                    NaN
# Alfa Long-Range Dual-Band AC1200 Wireless USB 3...                       NaN
# Amazon Echo Dot 3rd Generation                                           NaN
# Apple 20W USB-C Power Adapter - iPhone Charger ...                       NaN
#
# user_id                                             64596d2ae640040030448085  \
# product
# AXE MEMORY Superb 512GB USB 3.1 SuperSpeed Flas...                       4.0
# Airpods Wireless Bluetooth Headphones                                    NaN
# Alfa Long-Range Dual-Band AC1200 Wireless USB 3...                       NaN
# Amazon Echo Dot 3rd Generation                                           NaN
# Apple 20W USB-C Power Adapter - iPhone Charger ...                       NaN
#
# user_id                                             64597748e640040030448168  \
# product
# AXE MEMORY Superb 512GB USB 3.1 SuperSpeed Flas...                       NaN
# Airpods Wireless Bluetooth Headphones                                    NaN
# Alfa Long-Range Dual-Band AC1200 Wireless USB 3...                       5.0
# Amazon Echo Dot 3rd Generation                                           NaN
# Apple 20W USB-C Power Adapter - iPhone Charger ...                       4.0
#
# user_id                                             645978e5e640040030448235  \
# product
# AXE MEMORY Superb 512GB USB 3.1 SuperSpeed Flas...                       3.0
# Airpods Wireless Bluetooth Headphones                                    NaN
# Alfa Long-Range Dual-Band AC1200 Wireless USB 3...                       2.0
# Amazon Echo Dot 3rd Generation                                           3.0
# Apple 20W USB-C Power Adapter - iPhone Charger ...                       4.0
#
# user_id                                             64598b04138df50030b79610
# product
# AXE MEMORY Superb 512GB USB 3.1 SuperSpeed Flas...                       5.0
# Airpods Wireless Bluetooth Headphones                                    NaN
# Alfa Long-Range Dual-Band AC1200 Wireless USB 3...                       1.0
# Amazon Echo Dot 3rd Generation                                           NaN
# Apple 20W USB-C Power Adapter - iPhone Charger ...                       1.0
#
# [5 rows x 26 columns]

# %%
corrMatrx=userRating.corr(method='pearson')
corrMatrx
# Out:
# user_id                   63e7989616745843a0c18b65  63e7989616745843a0c18b66  \
# user_id
# 63e7989616745843a0c18b65                       NaN                       NaN
# 63e7989616745843a0c18b66                       NaN                       NaN
# 63e7989616745843a0c18b68                       NaN                       NaN
# 63e7989616745843a0c18b69                       NaN                       NaN
# 63e7989616745843a0c18b6a                       NaN                       NaN
# 63e7989616745843a0c18b73                       NaN                       NaN
# 63e7989616745843a0c18b75                       NaN                       NaN
# 63e7989616745843a0c18b76                       NaN                       NaN
# 63e7989616745843a0c18b77                       NaN                       NaN
# 63e7989616745843a0c18b78                       NaN                       NaN
# 63e7989616745843a0c18b79                       NaN                       NaN
# 63e7989616745843a0c18b7a                       NaN                       NaN
# 63e7989616745843a0c18b7b                       NaN                       NaN
# 64497143a7426d0030f2b6cb                       NaN                       NaN
# 644a57fd4d690900314fa708                       NaN                       NaN
# 644a5a8b4d690900314fa72d                       NaN                       NaN
# 644a5db34d690900314fa784                       NaN                       NaN
# 644a5f6a4d690900314fa7a7                       NaN                       NaN
# 644a61534d690900314fa7dd                       NaN                       NaN
# 644a63374d690900314fa808                       NaN                       NaN
# 644a65014d690900314fa839                       NaN                       NaN
# 6456380e9c6e6400328bd2e4                       NaN                       NaN
# 64596d2ae640040030448085                       NaN                       NaN
# 64597748e640040030448168                       NaN                       NaN
# 645978e5e640040030448235                       NaN                       NaN
# 64598b04138df50030b79610                       NaN                       NaN
#
# user_id                   63e7989616745843a0c18b68  63e7989616745843a0c18b69  \
# user_id
# 63e7989616745843a0c18b65                       NaN                       NaN
# 63e7989616745843a0c18b66                       NaN                       NaN
# 63e7989616745843a0c18b68                       1.0                       NaN
# 63e7989616745843a0c18b69                       NaN                       1.0
# 63e7989616745843a0c18b6a                       NaN                       0.5
# 63e7989616745843a0c18b73                       NaN                       NaN
# 63e7989616745843a0c18b75                      -1.0                       NaN
# 63e7989616745843a0c18b76                       NaN                       NaN
# 63e7989616745843a0c18b77                      -1.0                       NaN
# 63e7989616745843a0c18b78                       NaN                       NaN
# 63e7989616745843a0c18b79                       NaN                       NaN
# 63e7989616745843a0c18b7a                       NaN                       NaN
# 63e7989616745843a0c18b7b                       NaN                       NaN
# 64497143a7426d0030f2b6cb                       NaN                       NaN
# 644a57fd4d690900314fa708                       NaN                       NaN
# 644a5a8b4d690900314fa72d                       NaN                       NaN
# 644a5db34d690900314fa784                       NaN                      -1.0
# 644a5f6a4d690900314fa7a7                       NaN                       1.0
# 644a61534d690900314fa7dd                       NaN                       NaN
# 644a63374d690900314fa808                       NaN                       NaN
# 644a65014d690900314fa839                       NaN                       NaN
# 6456380e9c6e6400328bd2e4                       NaN                       NaN
# 64596d2ae640040030448085                       NaN                       NaN
# 64597748e640040030448168                       NaN                       NaN
# 645978e5e640040030448235                       NaN                       NaN
# 64598b04138df50030b79610                       NaN                       NaN
#
# user_id                   63e7989616745843a0c18b6a  63e7989616745843a0c18b73  \
# user_id
# 63e7989616745843a0c18b65                       NaN                       NaN
# 63e7989616745843a0c18b66                       NaN                       NaN
# 63e7989616745843a0c18b68                       NaN                       NaN
# 63e7989616745843a0c18b69                       0.5                       NaN
# 63e7989616745843a0c18b6a                       1.0                       NaN
# 63e7989616745843a0c18b73                       NaN                       NaN
# 63e7989616745843a0c18b75                       NaN                       NaN
# 63e7989616745843a0c18b76                       NaN                       NaN
# 63e7989616745843a0c18b77                       NaN                       NaN
# 63e7989616745843a0c18b78                       NaN                       NaN
# 63e7989616745843a0c18b79                       NaN                       NaN
# 63e7989616745843a0c18b7a                       NaN                       NaN
# 63e7989616745843a0c18b7b                       NaN                       NaN
# 64497143a7426d0030f2b6cb                       NaN                       NaN
# 644a57fd4d690900314fa708                       NaN                       NaN
# 644a5a8b4d690900314fa72d                       NaN                       NaN
# 644a5db34d690900314fa784                      -0.5                       NaN
# 644a5f6a4d690900314fa7a7                       0.5                       NaN
# 644a61534d690900314fa7dd                       NaN                       NaN
# 644a63374d690900314fa808                       NaN                       NaN
# 644a65014d690900314fa839                       NaN                       NaN
# 6456380e9c6e6400328bd2e4                       NaN                       NaN
# 64596d2ae640040030448085                      -1.0                       NaN
# 64597748e640040030448168                       NaN                       NaN
# 645978e5e640040030448235                       NaN                       NaN
# 64598b04138df50030b79610                       NaN                       NaN
#
# user_id                   63e7989616745843a0c18b75  63e7989616745843a0c18b76  \
# user_id
# 63e7989616745843a0c18b65                       NaN                       NaN
# 63e7989616745843a0c18b66                       NaN                       NaN
# 63e7989616745843a0c18b68                 -1.000000                       NaN
# 63e7989616745843a0c18b69                       NaN                       NaN
# 63e7989616745843a0c18b6a                       NaN                       NaN
# 63e7989616745843a0c18b73                       NaN                       NaN
# 63e7989616745843a0c18b75                  1.000000                       NaN
# 63e7989616745843a0c18b76                       NaN                       NaN
# 63e7989616745843a0c18b77                  0.995871                       NaN
# 63e7989616745843a0c18b78                       NaN                       NaN
# 63e7989616745843a0c18b79                       NaN                       NaN
# 63e7989616745843a0c18b7a                       NaN                       NaN
# 63e7989616745843a0c18b7b                       NaN                       NaN
# 64497143a7426d0030f2b6cb                       NaN                       NaN
# 644a57fd4d690900314fa708                       NaN                       NaN
# 644a5a8b4d690900314fa72d                       NaN                       NaN
# 644a5db34d690900314fa784                       NaN                       NaN
# 644a5f6a4d690900314fa7a7                       NaN                       NaN
# 644a61534d690900314fa7dd                  1.000000                       NaN
# 644a63374d690900314fa808                       NaN                       NaN
# 644a65014d690900314fa839                       NaN                       NaN
# 6456380e9c6e6400328bd2e4                       NaN                       NaN
# 64596d2ae640040030448085                       NaN                       NaN
# 64597748e640040030448168                       NaN                       NaN
# 645978e5e640040030448235                       NaN                       NaN
# 64598b04138df50030b79610                       NaN                       NaN
#
# user_id                   63e7989616745843a0c18b77  63e7989616745843a0c18b78  \
# user_id
# 63e7989616745843a0c18b65                       NaN                       NaN
# 63e7989616745843a0c18b66                       NaN                       NaN
# 63e7989616745843a0c18b68                 -1.000000                       NaN
# 63e7989616745843a0c18b69                       NaN                       NaN
# 63e7989616745843a0c18b6a                       NaN                       NaN
# 63e7989616745843a0c18b73                       NaN                       NaN
# 63e7989616745843a0c18b75                  0.995871                       NaN
# 63e7989616745843a0c18b76                       NaN                       NaN
# 63e7989616745843a0c18b77                  1.000000                       NaN
# 63e7989616745843a0c18b78                       NaN                       1.0
# 63e7989616745843a0c18b79                       NaN                       NaN
# 63e7989616745843a0c18b7a                  1.000000                       NaN
# 63e7989616745843a0c18b7b                       NaN                       NaN
# 64497143a7426d0030f2b6cb                       NaN                       NaN
# 644a57fd4d690900314fa708                 -1.000000                       NaN
# 644a5a8b4d690900314fa72d                  0.258199                       NaN
# 644a5db34d690900314fa784                  1.000000                       1.0
# 644a5f6a4d690900314fa7a7                  0.766965                       NaN
# 644a61534d690900314fa7dd                  0.968330                       NaN
# 644a63374d690900314fa808                  0.052414                       NaN
# 644a65014d690900314fa839                       NaN                       NaN
# 6456380e9c6e6400328bd2e4                       NaN                       NaN
# 64596d2ae640040030448085                       NaN                       NaN
# 64597748e640040030448168                       NaN                       NaN
# 645978e5e640040030448235                       NaN                       NaN
# 64598b04138df50030b79610                       NaN                       NaN
#
# user_id                   ...  644a5db34d690900314fa784  \
# user_id                   ...
# 63e7989616745843a0c18b65  ...                       NaN
# 63e7989616745843a0c18b66  ...                       NaN
# 63e7989616745843a0c18b68  ...                       NaN
# 63e7989616745843a0c18b69  ...             -1.000000e+00
# 63e7989616745843a0c18b6a  ...             -5.000000e-01
# 63e7989616745843a0c18b73  ...                       NaN
# 63e7989616745843a0c18b75  ...                       NaN
# 63e7989616745843a0c18b76  ...                       NaN
# 63e7989616745843a0c18b77  ...              1.000000e+00
# 63e7989616745843a0c18b78  ...              1.000000e+00
# 63e7989616745843a0c18b79  ...                       NaN
# 63e7989616745843a0c18b7a  ...                       NaN
# 63e7989616745843a0c18b7b  ...             -1.000000e+00
# 64497143a7426d0030f2b6cb  ...                       NaN
# 644a57fd4d690900314fa708  ...             -8.528029e-01
# 644a5a8b4d690900314fa72d  ...              8.664002e-01
# 644a5db34d690900314fa784  ...              1.000000e+00
# 644a5f6a4d690900314fa7a7  ...              4.547940e-01
# 644a61534d690900314fa7dd  ...                       NaN
# 644a63374d690900314fa808  ...             -1.000000e+00
# 644a65014d690900314fa839  ...             -5.000000e-01
# 6456380e9c6e6400328bd2e4  ...                       NaN
# 64596d2ae640040030448085  ...              2.500000e-01
# 64597748e640040030448168  ...                       NaN
# 645978e5e640040030448235  ...              1.313634e-16
# 64598b04138df50030b79610  ...             -1.000000e+00
#
# user_id                   644a5f6a4d690900314fa7a7  644a61534d690900314fa7dd  \
# user_id
# 63e7989616745843a0c18b65                       NaN                       NaN
# 63e7989616745843a0c18b66                       NaN                       NaN
# 63e7989616745843a0c18b68                       NaN                       NaN
# 63e7989616745843a0c18b69                  1.000000                       NaN
# 63e7989616745843a0c18b6a                  0.500000                       NaN
# 63e7989616745843a0c18b73                       NaN                       NaN
# 63e7989616745843a0c18b75                       NaN                   1.00000
# 63e7989616745843a0c18b76                       NaN                       NaN
# 63e7989616745843a0c18b77                  0.766965                   0.96833
# 63e7989616745843a0c18b78                       NaN                       NaN
# 63e7989616745843a0c18b79                       NaN                       NaN
# 63e7989616745843a0c18b7a                  1.000000                       NaN
# 63e7989616745843a0c18b7b                       NaN                       NaN
# 64497143a7426d0030f2b6cb                       NaN                       NaN
# 644a57fd4d690900314fa708                       NaN                       NaN
# 644a5a8b4d690900314fa72d                  0.916555                       NaN
# 644a5db34d690900314fa784                  0.454794                       NaN
# 644a5f6a4d690900314fa7a7                  1.000000                   1.00000
# 644a61534d690900314fa7dd                  1.000000                   1.00000
# 644a63374d690900314fa808                 -1.000000                   1.00000
# 644a65014d690900314fa839                       NaN                       NaN
# 6456380e9c6e6400328bd2e4                       NaN                       NaN
# 64596d2ae640040030448085                 -0.373751                       NaN
# 64597748e640040030448168                 -0.089087                       NaN
# 645978e5e640040030448235                  0.591864                       NaN
# 64598b04138df50030b79610                 -0.061337                       NaN
#
# user_id                   644a63374d690900314fa808  644a65014d690900314fa839  \
# user_id
# 63e7989616745843a0c18b65                       NaN                       NaN
# 63e7989616745843a0c18b66                       NaN                       NaN
# 63e7989616745843a0c18b68                       NaN                       NaN
# 63e7989616745843a0c18b69                       NaN                       NaN
# 63e7989616745843a0c18b6a                       NaN                       NaN
# 63e7989616745843a0c18b73                       NaN                       NaN
# 63e7989616745843a0c18b75                       NaN                       NaN
# 63e7989616745843a0c18b76                       NaN                       NaN
# 63e7989616745843a0c18b77                  0.052414                       NaN
# 63e7989616745843a0c18b78                       NaN                       NaN
# 63e7989616745843a0c18b79                       NaN                       NaN
# 63e7989616745843a0c18b7a                       NaN                       NaN
# 63e7989616745843a0c18b7b                  1.000000                       NaN
# 64497143a7426d0030f2b6cb                       NaN                       NaN
# 644a57fd4d690900314fa708                       NaN                       NaN
# 644a5a8b4d690900314fa72d                 -0.327327                 -0.188982
# 644a5db34d690900314fa784                 -1.000000                 -0.500000
# 644a5f6a4d690900314fa7a7                 -1.000000                       NaN
# 644a61534d690900314fa7dd                  1.000000                       NaN
# 644a63374d690900314fa808                  1.000000                       NaN
# 644a65014d690900314fa839                       NaN                  1.000000
# 6456380e9c6e6400328bd2e4                       NaN                       NaN
# 64596d2ae640040030448085                       NaN                       NaN
# 64597748e640040030448168                       NaN                       NaN
# 645978e5e640040030448235                       NaN                  1.000000
# 64598b04138df50030b79610                       NaN                       NaN
#
# user_id                   6456380e9c6e6400328bd2e4  64596d2ae640040030448085  \
# user_id
# 63e7989616745843a0c18b65                       NaN                       NaN
# 63e7989616745843a0c18b66                       NaN                       NaN
# 63e7989616745843a0c18b68                       NaN                       NaN
# 63e7989616745843a0c18b69                       NaN                       NaN
# 63e7989616745843a0c18b6a                       NaN                 -1.000000
# 63e7989616745843a0c18b73                       NaN                       NaN
# 63e7989616745843a0c18b75                       NaN                       NaN
# 63e7989616745843a0c18b76                       NaN                       NaN
# 63e7989616745843a0c18b77                       NaN                       NaN
# 63e7989616745843a0c18b78                       NaN                       NaN
# 63e7989616745843a0c18b79                       NaN                       NaN
# 63e7989616745843a0c18b7a                       NaN                       NaN
# 63e7989616745843a0c18b7b                       NaN                       NaN
# 64497143a7426d0030f2b6cb                       NaN                       NaN
# 644a57fd4d690900314fa708                       NaN                 -1.000000
# 644a5a8b4d690900314fa72d                       NaN                 -0.500000
# 644a5db34d690900314fa784                       NaN                  0.250000
# 644a5f6a4d690900314fa7a7                       NaN                 -0.373751
# 644a61534d690900314fa7dd                       NaN                       NaN
# 644a63374d690900314fa808                       NaN                       NaN
# 644a65014d690900314fa839                       NaN                       NaN
# 6456380e9c6e6400328bd2e4                       1.0                       NaN
# 64596d2ae640040030448085                       NaN                  1.000000
# 64597748e640040030448168                       NaN                       NaN
# 645978e5e640040030448235                       NaN                 -0.628768
# 64598b04138df50030b79610                       NaN                  0.216024
#
# user_id                   64597748e640040030448168  645978e5e640040030448235  \
# user_id
# 63e7989616745843a0c18b65                       NaN                       NaN
# 63e7989616745843a0c18b66                       NaN                       NaN
# 63e7989616745843a0c18b68                       NaN                       NaN
# 63e7989616745843a0c18b69                       NaN                       NaN
# 63e7989616745843a0c18b6a                       NaN                       NaN
# 63e7989616745843a0c18b73                       NaN                       NaN
# 63e7989616745843a0c18b75                       NaN                       NaN
# 63e7989616745843a0c18b76                       NaN                       NaN
# 63e7989616745843a0c18b77                       NaN                       NaN
# 63e7989616745843a0c18b78                       NaN                       NaN
# 63e7989616745843a0c18b79                       NaN                       NaN
# 63e7989616745843a0c18b7a                       NaN                       NaN
# 63e7989616745843a0c18b7b                       NaN                       NaN
# 64497143a7426d0030f2b6cb                       NaN                       NaN
# 644a57fd4d690900314fa708                       NaN                       NaN
# 644a5a8b4d690900314fa72d                 -1.000000              1.000000e+00
# 644a5db34d690900314fa784                       NaN              1.313634e-16
# 644a5f6a4d690900314fa7a7                 -0.089087              5.918640e-01
# 644a61534d690900314fa7dd                       NaN                       NaN
# 644a63374d690900314fa808                       NaN                       NaN
# 644a65014d690900314fa839                       NaN              1.000000e+00
# 6456380e9c6e6400328bd2e4                       NaN                       NaN
# 64596d2ae640040030448085                       NaN             -6.287677e-01
# 64597748e640040030448168                  1.000000             -4.731969e-01
# 645978e5e640040030448235                 -0.473197              1.000000e+00
# 64598b04138df50030b79610                  0.060146             -3.112864e-01
#
# user_id                   64598b04138df50030b79610
# user_id
# 63e7989616745843a0c18b65                       NaN
# 63e7989616745843a0c18b66                       NaN
# 63e7989616745843a0c18b68                       NaN
# 63e7989616745843a0c18b69                       NaN
# 63e7989616745843a0c18b6a                       NaN
# 63e7989616745843a0c18b73                       NaN
# 63e7989616745843a0c18b75                       NaN
# 63e7989616745843a0c18b76                       NaN
# 63e7989616745843a0c18b77                       NaN
# 63e7989616745843a0c18b78                       NaN
# 63e7989616745843a0c18b79                       NaN
# 63e7989616745843a0c18b7a                       NaN
# 63e7989616745843a0c18b7b                       NaN
# 64497143a7426d0030f2b6cb                       NaN
# 644a57fd4d690900314fa708                       NaN
# 644a5a8b4d690900314fa72d                       NaN
# 644a5db34d690900314fa784                 -1.000000
# 644a5f6a4d690900314fa7a7                 -0.061337
# 644a61534d690900314fa7dd                       NaN
# 644a63374d690900314fa808                       NaN
# 644a65014d690900314fa839                       NaN
# 6456380e9c6e6400328bd2e4                       NaN
# 64596d2ae640040030448085                  0.216024
# 64597748e640040030448168                  0.060146
# 645978e5e640040030448235                 -0.311286
# 64598b04138df50030b79610                  1.000000
#
# [26 rows x 26 columns]

# %%
userRating.fillna(0,inplace=True)

# %%
userRating
# Out:
# user_id                                             63e7989616745843a0c18b65  \
# product
# AXE MEMORY Superb 512GB USB 3.1 SuperSpeed Flas...                       0.0
# Airpods Wireless Bluetooth Headphones                                    0.0
# Alfa Long-Range Dual-Band AC1200 Wireless USB 3...                       0.0
# Amazon Echo Dot 3rd Generation                                           0.0
# Apple 20W USB-C Power Adapter - iPhone Charger ...                       0.0
# Apple MagSafe Charger - Wireless Charger with F...                       0.0
# Apple iPad Pro                                                           0.0
# Beats by Dre Powerbeats Pro Wireless Earphones                           0.0
# Boytone - 2500W 2.1-Ch. Home Theater System - B...                       0.0
# Cannon EOS 80D DSLR Camera                                               0.0
# Canon EOS Rebel T7 DSLR Camera                                           0.0
# Canon EOS Rebel T7 DSLR Camera|2 Lens Kit with ...                       0.0
# DJI Air 2S, Drone Quadcopter UAV with 3-Axis Gi...                       0.0
# DJI Avata Explorer Combo - First-Person View Dr...                       0.0
# HP Reverb G2 VR Headset with Controller, Adjust...                       0.0
# HyperX Cloud II - Gaming Headset, 7.1 Surround ...                       5.0
# HyperX QuadCast S – RGB USB Condenser Microphon...                       0.0
# Intex Wired Gaming KB+MS (IT-KB334) Combo Set                            0.0
# Jabra PanaCast – Intelligent 180° Panoramic-4K ...                       0.0
# Keyboard                                                                 0.0
# Kindle Paperwhite (16 GB) – Now with a 6.8" dis...                       0.0
# Kindle Paperwhite Signature Edition Essentials ...                       0.0
# LEGO Marvel Infinity Gauntlet Set 76191, Collec...                       0.0
# Lenovo 00WG780 Enterprise Entry S3510 480GB SAT...                       0.0
# Lenovo D3-S4610 960 GB Solid State Drive - 2.5"...                       0.0
# Logitech C920x HD Pro Webcam, Full HD 1080p/30f...                       0.0
# Logitech G-Series Gaming Mouse                                           0.0
# Lowepro - Slingshot Edge 250 AW Camera Backpack...                       0.0
# Meta Quest 2 — Advanced All-In-One Virtual Real...                       0.0
# Microsoft Surface Pro 8 - 13" Touchscreen - Int...                       0.0
# Nike Air Max 270 React                                                   0.0
# Ninja SP101 Digital Air Fry Countertop Oven wit...                       0.0
# Nintendo Neon Purple/ Neon Orange Joy-Con (L-R)...                       0.0
# Oyen Digital Helix Dura 4TB USB-C (USB 3.2 Gen2...                       0.0
# PROGRACE Kids Camera Waterproof Boys - Toy Gift...                       0.0
# Playstation Sony 4, 500GB Slim System [CUH-2215...                       0.0
# Polaroid IS048 Digital Camera - Small Lightweig...                       0.0
# PowerA Enhanced Wireless Controller for Nintend...                       0.0
# Sample nameSpinBot Combo Pack Of BattleMods X1 ...                       0.0
# Sample nameTechGuy4u One Handed Gaming Keyboard...                       0.0
# Sample nameWoomzy Mini Hand Free Portable Neckb...                       0.0
# Samsung Galaxy S20 Ultra                                                 0.0
# SanDisk 64GB Ultra MicroSDXC UHS-I Memory Card ...                       0.0
# SanDisk Ultra 32GB Class 10 SDHC UHS-I Memory C...                       0.0
# Sanus VLF410B1 10-Inch Super Slim Full-Motion M...                       0.0
# Sony Compact Stereo Lavalier Microphone ECMLV1                           0.0
# Sony PlayStation 5 Console                                               0.0
# Sony Playstation 4 Pro White Version                                     0.0
# TP-Link Nano USB Wifi Dongle 150Mbps High Gain ...                       0.0
# Wacom Cintiq 16 Drawing Tablet with Full HD 15....                       0.0
# Wacom Intuos Small Graphics Drawing Tablet, inc...                       0.0
# amd Ryzen 5 5600G 3.9 GHz Upto 4.4 GHz AM4 Sock...                       0.0
# iPhone 11 Pro 256GB Memory                                               0.0
#
# user_id                                             63e7989616745843a0c18b66  \
# product
# AXE MEMORY Superb 512GB USB 3.1 SuperSpeed Flas...                       0.0
# Airpods Wireless Bluetooth Headphones                                    5.0
# Alfa Long-Range Dual-Band AC1200 Wireless USB 3...                       0.0
# Amazon Echo Dot 3rd Generation                                           0.0
# Apple 20W USB-C Power Adapter - iPhone Charger ...                       0.0
# Apple MagSafe Charger - Wireless Charger with F...                       0.0
# Apple iPad Pro                                                           0.0
# Beats by Dre Powerbeats Pro Wireless Earphones                           0.0
# Boytone - 2500W 2.1-Ch. Home Theater System - B...                       0.0
# Cannon EOS 80D DSLR Camera                                               0.0
# Canon EOS Rebel T7 DSLR Camera                                           0.0
# Canon EOS Rebel T7 DSLR Camera|2 Lens Kit with ...                       0.0
# DJI Air 2S, Drone Quadcopter UAV with 3-Axis Gi...                       0.0
# DJI Avata Explorer Combo - First-Person View Dr...                       0.0
# HP Reverb G2 VR Headset with Controller, Adjust...                       0.0
# HyperX Cloud II - Gaming Headset, 7.1 Surround ...                       0.0
# HyperX QuadCast S – RGB USB Condenser Microphon...                       0.0
# Intex Wired Gaming KB+MS (IT-KB334) Combo Set                            0.0
# Jabra PanaCast – Intelligent 180° Panoramic-4K ...                       0.0
# Keyboard                                                                 0.0
# Kindle Paperwhite (16 GB) – Now with a 6.8" dis...                       0.0
# Kindle Paperwhite Signature Edition Essentials ...                       0.0
# LEGO Marvel Infinity Gauntlet Set 76191, Collec...                       0.0
# Lenovo 00WG780 Enterprise Entry S3510 480GB SAT...                       0.0
# Lenovo D3-S4610 960 GB Solid State Drive - 2.5"...                       0.0
# Logitech C920x HD Pro Webcam, Full HD 1080p/30f...                       0.0
# Logitech G-Series Gaming Mouse                                           0.0
# Lowepro - Slingshot Edge 250 AW Camera Backpack...                       0.0
# Meta Quest 2 — Advanced All-In-One Virtual Real...                       0.0
# Microsoft Surface Pro 8 - 13" Touchscreen - Int...                       0.0
# Nike Air Max 270 React                                                   0.0
# Ninja SP101 Digital Air Fry Countertop Oven wit...                       0.0
# Nintendo Neon Purple/ Neon Orange Joy-Con (L-R)...                       0.0
# Oyen Digital Helix Dura 4TB USB-C (USB 3.2 Gen2...                       0.0
# PROGRACE Kids Camera Waterproof Boys - Toy Gift...                       0.0
# Playstation Sony 4, 500GB Slim System [CUH-2215...                       0.0
# Polaroid IS048 Digital Camera - Small Lightweig...                       0.0
# PowerA Enhanced Wireless Controller for Nintend...                       0.0
# Sample nameSpinBot Combo Pack Of BattleMods X1 ...                       0.0
# Sample nameTechGuy4u One Handed Gaming Keyboard...                       0.0
# Sample nameWoomzy Mini Hand Free Portable Neckb...                       0.0
# Samsung Galaxy S20 Ultra                                                 0.0
# SanDisk 64GB Ultra MicroSDXC UHS-I Memory Card ...                       0.0
# SanDisk Ultra 32GB Class 10 SDHC UHS-I Memory C...                       0.0
# Sanus VLF410B1 10-Inch Super Slim Full-Motion M...                       0.0
# Sony Compact Stereo Lavalier Microphone ECMLV1                           0.0
# Sony PlayStation 5 Console                                               0.0
# Sony Playstation 4 Pro White Version                                     0.0
# TP-Link Nano USB Wifi Dongle 150Mbps High Gain ...                       0.0
# Wacom Cintiq 16 Drawing Tablet with Full HD 15....                       0.0
# Wacom Intuos Small Graphics Drawing Tablet, inc...                       0.0
# amd Ryzen 5 5600G 3.9 GHz Upto 4.4 GHz AM4 Sock...                       0.0
# iPhone 11 Pro 256GB Memory                                               0.0
#
# user_id                                             63e7989616745843a0c18b68  \
# product
# AXE MEMORY Superb 512GB USB 3.1 SuperSpeed Flas...                       0.0
# Airpods Wireless Bluetooth Headphones                                    5.0
# Alfa Long-Range Dual-Band AC1200 Wireless USB 3...                       0.0
# Amazon Echo Dot 3rd Generation                                           0.0
# Apple 20W USB-C Power Adapter - iPhone Charger ...                       0.0
# Apple MagSafe Charger - Wireless Charger with F...                       0.0
# Apple iPad Pro                                                           0.0
# Beats by Dre Powerbeats Pro Wireless Earphones                           0.0
# Boytone - 2500W 2.1-Ch. Home Theater System - B...                       0.0
# Cannon EOS 80D DSLR Camera                                               5.0
# Canon EOS Rebel T7 DSLR Camera                                           0.0
# Canon EOS Rebel T7 DSLR Camera|2 Lens Kit with ...                       0.0
# DJI Air 2S, Drone Quadcopter UAV with 3-Axis Gi...                       0.0
# DJI Avata Explorer Combo - First-Person View Dr...                       0.0
# HP Reverb G2 VR Headset with Controller, Adjust...                       0.0
# HyperX Cloud II - Gaming Headset, 7.1 Surround ...                       0.0
# HyperX QuadCast S – RGB USB Condenser Microphon...                       0.0
# Intex Wired Gaming KB+MS (IT-KB334) Combo Set                            0.0
# Jabra PanaCast – Intelligent 180° Panoramic-4K ...                       0.0
# Keyboard                                                                 0.0
# Kindle Paperwhite (16 GB) – Now with a 6.8" dis...                       0.0
# Kindle Paperwhite Signature Edition Essentials ...                       0.0
# LEGO Marvel Infinity Gauntlet Set 76191, Collec...                       0.0
# Lenovo 00WG780 Enterprise Entry S3510 480GB SAT...                       0.0
# Lenovo D3-S4610 960 GB Solid State Drive - 2.5"...                       0.0
# Logitech C920x HD Pro Webcam, Full HD 1080p/30f...                       0.0
# Logitech G-Series Gaming Mouse                                           2.0
# Lowepro - Slingshot Edge 250 AW Camera Backpack...                       0.0
# Meta Quest 2 — Advanced All-In-One Virtual Real...                       0.0
# Microsoft Surface Pro 8 - 13" Touchscreen - Int...                       0.0
# Nike Air Max 270 React                                                   0.0
# Ninja SP101 Digital Air Fry Countertop Oven wit...                       0.0
# Nintendo Neon Purple/ Neon Orange Joy-Con (L-R)...                       0.0
# Oyen Digital Helix Dura 4TB USB-C (USB 3.2 Gen2...                       0.0
# PROGRACE Kids Camera Waterproof Boys - Toy Gift...                       0.0
# Playstation Sony 4, 500GB Slim System [CUH-2215...                       0.0
# Polaroid IS048 Digital Camera - Small Lightweig...                       0.0
# PowerA Enhanced Wireless Controller for Nintend...                       0.0
# Sample nameSpinBot Combo Pack Of BattleMods X1 ...                       0.0
# Sample nameTechGuy4u One Handed Gaming Keyboard...                       0.0
# Sample nameWoomzy Mini Hand Free Portable Neckb...                       0.0
# Samsung Galaxy S20 Ultra                                                 0.0
# SanDisk 64GB Ultra MicroSDXC UHS-I Memory Card ...                       0.0
# SanDisk Ultra 32GB Class 10 SDHC UHS-I Memory C...                       0.0
# Sanus VLF410B1 10-Inch Super Slim Full-Motion M...                       0.0
# Sony Compact Stereo Lavalier Microphone ECMLV1                           0.0
# Sony PlayStation 5 Console                                               0.0
# Sony Playstation 4 Pro White Version                                     0.0
# TP-Link Nano USB Wifi Dongle 150Mbps High Gain ...                       0.0
# Wacom Cintiq 16 Drawing Tablet with Full HD 15....                       0.0
# Wacom Intuos Small Graphics Drawing Tablet, inc...                       0.0
# amd Ryzen 5 5600G 3.9 GHz Upto 4.4 GHz AM4 Sock...                       0.0
# iPhone 11 Pro 256GB Memory                                               4.0
#
# user_id                                             63e7989616745843a0c18b69  \
# product
# AXE MEMORY Superb 512GB USB 3.1 SuperSpeed Flas...                       0.0
# Airpods Wireless Bluetooth Headphones                                    0.0
# Alfa Long-Range Dual-Band AC1200 Wireless USB 3...                       0.0
# Amazon Echo Dot 3rd Generation                                           0.0
# Apple 20W USB-C Power Adapter - iPhone Charger ...                       0.0
# Apple MagSafe Charger - Wireless Charger with F...                       0.0
# Apple iPad Pro                                                           0.0
# Beats by Dre Powerbeats Pro Wireless Earphones                           0.0
# Boytone - 2500W 2.1-Ch. Home Theater System - B...                       5.0
# Cannon EOS 80D DSLR Camera                                               0.0
# Canon EOS Rebel T7 DSLR Camera                                           0.0
# Canon EOS Rebel T7 DSLR Camera|2 Lens Kit with ...                       0.0
# DJI Air 2S, Drone Quadcopter UAV with 3-Axis Gi...                       0.0
# DJI Avata Explorer Combo - First-Person View Dr...                       0.0
# HP Reverb G2 VR Headset with Controller, Adjust...                       0.0
# HyperX Cloud II - Gaming Headset, 7.1 Surround ...                       0.0
# HyperX QuadCast S – RGB USB Condenser Microphon...                       0.0
# Intex Wired Gaming KB+MS (IT-KB334) Combo Set                            0.0
# Jabra PanaCast – Intelligent 180° Panoramic-4K ...                       0.0
# Keyboard                                                                 0.0
# Kindle Paperwhite (16 GB) – Now with a 6.8" dis...                       0.0
# Kindle Paperwhite Signature Edition Essentials ...                       0.0
# LEGO Marvel Infinity Gauntlet Set 76191, Collec...                       0.0
# Lenovo 00WG780 Enterprise Entry S3510 480GB SAT...                       0.0
# Lenovo D3-S4610 960 GB Solid State Drive - 2.5"...                       0.0
# Logitech C920x HD Pro Webcam, Full HD 1080p/30f...                       0.0
# Logitech G-Series Gaming Mouse                                           0.0
# Lowepro - Slingshot Edge 250 AW Camera Backpack...                       4.0
# Meta Quest 2 — Advanced All-In-One Virtual Real...                       0.0
# Microsoft Surface Pro 8 - 13" Touchscreen - Int...                       0.0
# Nike Air Max 270 React                                                   0.0
# Ninja SP101 Digital Air Fry Countertop Oven wit...                       0.0
# Nintendo Neon Purple/ Neon Orange Joy-Con (L-R)...                       0.0
# Oyen Digital Helix Dura 4TB USB-C (USB 3.2 Gen2...                       0.0
# PROGRACE Kids Camera Waterproof Boys - Toy Gift...                       0.0
# Playstation Sony 4, 500GB Slim System [CUH-2215...                       0.0
# Polaroid IS048 Digital Camera - Small Lightweig...                       0.0
# PowerA Enhanced Wireless Controller for Nintend...                       0.0
# Sample nameSpinBot Combo Pack Of BattleMods X1 ...                       0.0
# Sample nameTechGuy4u One Handed Gaming Keyboard...                       0.0
# Sample nameWoomzy Mini Hand Free Portable Neckb...                       0.0
# Samsung Galaxy S20 Ultra                                                 0.0
# SanDisk 64GB Ultra MicroSDXC UHS-I Memory Card ...                       0.0
# SanDisk Ultra 32GB Class 10 SDHC UHS-I Memory C...                       0.0
# Sanus VLF410B1 10-Inch Super Slim Full-Motion M...                       4.0
# Sony Compact Stereo Lavalier Microphone ECMLV1                           0.0
# Sony PlayStation 5 Console                                               0.0
# Sony Playstation 4 Pro White Version                                     0.0
# TP-Link Nano USB Wifi Dongle 150Mbps High Gain ...                       0.0
# Wacom Cintiq 16 Drawing Tablet with Full HD 15....                       0.0
# Wacom Intuos Small Graphics Drawing Tablet, inc...                       0.0
# amd Ryzen 5 5600G 3.9 GHz Upto 4.4 GHz AM4 Sock...                       0.0
# iPhone 11 Pro 256GB Memory                                               0.0
#
# user_id                                             63e7989616745843a0c18b6a  \
# product
# AXE MEMORY Superb 512GB USB 3.1 SuperSpeed Flas...                       0.0
# Airpods Wireless Bluetooth Headphones                                    0.0
# Alfa Long-Range Dual-Band AC1200 Wireless USB 3...                       0.0
# Amazon Echo Dot 3rd Generation                                           0.0
# Apple 20W USB-C Power Adapter - iPhone Charger ...                       0.0
# Apple MagSafe Charger - Wireless Charger with F...                       0.0
# Apple iPad Pro                                                           0.0
# Beats by Dre Powerbeats Pro Wireless Earphones                           0.0
# Boytone - 2500W 2.1-Ch. Home Theater System - B...                       4.0
# Cannon EOS 80D DSLR Camera                                               0.0
# Canon EOS Rebel T7 DSLR Camera                                           0.0
# Canon EOS Rebel T7 DSLR Camera|2 Lens Kit with ...                       0.0
# DJI Air 2S, Drone Quadcopter UAV with 3-Axis Gi...                       0.0
# DJI Avata Explorer Combo - First-Person View Dr...                       0.0
# HP Reverb G2 VR Headset with Controller, Adjust...                       0.0
# HyperX Cloud II - Gaming Headset, 7.1 Surround ...                       0.0
# HyperX QuadCast S – RGB USB Condenser Microphon...                       0.0
# Intex Wired Gaming KB+MS (IT-KB334) Combo Set                            0.0
# Jabra PanaCast – Intelligent 180° Panoramic-4K ...                       0.0
# Keyboard                                                                 0.0
# Kindle Paperwhite (16 GB) – Now with a 6.8" dis...                       0.0
# Kindle Paperwhite Signature Edition Essentials ...                       0.0
# LEGO Marvel Infinity Gauntlet Set 76191, Collec...                       0.0
# Lenovo 00WG780 Enterprise Entry S3510 480GB SAT...                       0.0
# Lenovo D3-S4610 960 GB Solid State Drive - 2.5"...                       0.0
# Logitech C920x HD Pro Webcam, Full HD 1080p/30f...                       0.0
# Logitech G-Series Gaming Mouse                                           0.0
# Lowepro - Slingshot Edge 250 AW Camera Backpack...                       4.0
# Meta Quest 2 — Advanced All-In-One Virtual Real...                       0.0
# Microsoft Surface Pro 8 - 13" Touchscreen - Int...                       0.0
# Nike Air Max 270 React                                                   0.0
# Ninja SP101 Digital Air Fry Countertop Oven wit...                       0.0
# Nintendo Neon Purple/ Neon Orange Joy-Con (L-R)...                       0.0
# Oyen Digital Helix Dura 4TB USB-C (USB 3.2 Gen2...                       0.0
# PROGRACE Kids Camera Waterproof Boys - Toy Gift...                       0.0
# Playstation Sony 4, 500GB Slim System [CUH-2215...                       0.0
# Polaroid IS048 Digital Camera - Small Lightweig...                       0.0
# PowerA Enhanced Wireless Controller for Nintend...                       0.0
# Sample nameSpinBot Combo Pack Of BattleMods X1 ...                       0.0
# Sample nameTechGuy4u One Handed Gaming Keyboard...                       0.0
# Sample nameWoomzy Mini Hand Free Portable Neckb...                       0.0
# Samsung Galaxy S20 Ultra                                                 0.0
# SanDisk 64GB Ultra MicroSDXC UHS-I Memory Card ...                       0.0
# SanDisk Ultra 32GB Class 10 SDHC UHS-I Memory C...                       0.0
# Sanus VLF410B1 10-Inch Super Slim Full-Motion M...                       3.0
# Sony Compact Stereo Lavalier Microphone ECMLV1                           0.0
# Sony PlayStation 5 Console                                               0.0
# Sony Playstation 4 Pro White Version                                     0.0
# TP-Link Nano USB Wifi Dongle 150Mbps High Gain ...                       0.0
# Wacom Cintiq 16 Drawing Tablet with Full HD 15....                       0.0
# Wacom Intuos Small Graphics Drawing Tablet, inc...                       0.0
# amd Ryzen 5 5600G 3.9 GHz Upto 4.4 GHz AM4 Sock...                       0.0
# iPhone 11 Pro 256GB Memory                                               0.0
#
# user_id                                             63e7989616745843a0c18b73  \
# product
# AXE MEMORY Superb 512GB USB 3.1 SuperSpeed Flas...                       0.0
# Airpods Wireless Bluetooth Headphones                                    0.0
# Alfa Long-Range Dual-Band AC1200 Wireless USB 3...                       0.0
# Amazon Echo Dot 3rd Generation                                           0.0
# Apple 20W USB-C Power Adapter - iPhone Charger ...                       0.0
# Apple MagSafe Charger - Wireless Charger with F...                       0.0
# Apple iPad Pro                                                           0.0
# Beats by Dre Powerbeats Pro Wireless Earphones                           0.0
# Boytone - 2500W 2.1-Ch. Home Theater System - B...                       0.0
# Cannon EOS 80D DSLR Camera                                               0.0
# Canon EOS Rebel T7 DSLR Camera                                           0.0
# Canon EOS Rebel T7 DSLR Camera|2 Lens Kit with ...                       0.0
# DJI Air 2S, Drone Quadcopter UAV with 3-Axis Gi...                       0.0
# DJI Avata Explorer Combo - First-Person View Dr...                       0.0
# HP Reverb G2 VR Headset with Controller, Adjust...                       0.0
# HyperX Cloud II - Gaming Headset, 7.1 Surround ...                       0.0
# HyperX QuadCast S – RGB USB Condenser Microphon...                       0.0
# Intex Wired Gaming KB+MS (IT-KB334) Combo Set                            0.0
# Jabra PanaCast – Intelligent 180° Panoramic-4K ...                       0.0
# Keyboard                                                                 0.0
# Kindle Paperwhite (16 GB) – Now with a 6.8" dis...                       0.0
# Kindle Paperwhite Signature Edition Essentials ...                       0.0
# LEGO Marvel Infinity Gauntlet Set 76191, Collec...                       0.0
# Lenovo 00WG780 Enterprise Entry S3510 480GB SAT...                       0.0
# Lenovo D3-S4610 960 GB Solid State Drive - 2.5"...                       0.0
# Logitech C920x HD Pro Webcam, Full HD 1080p/30f...                       0.0
# Logitech G-Series Gaming Mouse                                           0.0
# Lowepro - Slingshot Edge 250 AW Camera Backpack...                       0.0
# Meta Quest 2 — Advanced All-In-One Virtual Real...                       0.0
# Microsoft Surface Pro 8 - 13" Touchscreen - Int...                       0.0
# Nike Air Max 270 React                                                   0.0
# Ninja SP101 Digital Air Fry Countertop Oven wit...                       0.0
# Nintendo Neon Purple/ Neon Orange Joy-Con (L-R)...                       0.0
# Oyen Digital Helix Dura 4TB USB-C (USB 3.2 Gen2...                       0.0
# PROGRACE Kids Camera Waterproof Boys - Toy Gift...                       0.0
# Playstation Sony 4, 500GB Slim System [CUH-2215...                       0.0
# Polaroid IS048 Digital Camera - Small Lightweig...                       0.0
# PowerA Enhanced Wireless Controller for Nintend...                       0.0
# Sample nameSpinBot Combo Pack Of BattleMods X1 ...                       0.0
# Sample nameTechGuy4u One Handed Gaming Keyboard...                       0.0
# Sample nameWoomzy Mini Hand Free Portable Neckb...                       0.0
# Samsung Galaxy S20 Ultra                                                 0.0
# SanDisk 64GB Ultra MicroSDXC UHS-I Memory Card ...                       0.0
# SanDisk Ultra 32GB Class 10 SDHC UHS-I Memory C...                       0.0
# Sanus VLF410B1 10-Inch Super Slim Full-Motion M...                       0.0
# Sony Compact Stereo Lavalier Microphone ECMLV1                           0.0
# Sony PlayStation 5 Console                                               0.0
# Sony Playstation 4 Pro White Version                                     0.0
# TP-Link Nano USB Wifi Dongle 150Mbps High Gain ...                       0.0
# Wacom Cintiq 16 Drawing Tablet with Full HD 15....                       0.0
# Wacom Intuos Small Graphics Drawing Tablet, inc...                       0.0
# amd Ryzen 5 5600G 3.9 GHz Upto 4.4 GHz AM4 Sock...                       0.0
# iPhone 11 Pro 256GB Memory                                               5.0
#
# user_id                                             63e7989616745843a0c18b75  \
# product
# AXE MEMORY Superb 512GB USB 3.1 SuperSpeed Flas...                       0.0
# Airpods Wireless Bluetooth Headphones                                    4.0
# Alfa Long-Range Dual-Band AC1200 Wireless USB 3...                       0.0
# Amazon Echo Dot 3rd Generation                                           0.0
# Apple 20W USB-C Power Adapter - iPhone Charger ...                       0.0
# Apple MagSafe Charger - Wireless Charger with F...                       0.0
# Apple iPad Pro                                                           0.0
# Beats by Dre Powerbeats Pro Wireless Earphones                           0.0
# Boytone - 2500W 2.1-Ch. Home Theater System - B...                       0.0
# Cannon EOS 80D DSLR Camera                                               0.0
# Canon EOS Rebel T7 DSLR Camera                                           0.0
# Canon EOS Rebel T7 DSLR Camera|2 Lens Kit with ...                       0.0
# DJI Air 2S, Drone Quadcopter UAV with 3-Axis Gi...                       0.0
# DJI Avata Explorer Combo - First-Person View Dr...                       0.0
# HP Reverb G2 VR Headset with Controller, Adjust...                       0.0
# HyperX Cloud II - Gaming Headset, 7.1 Surround ...                       0.0
# HyperX QuadCast S – RGB USB Condenser Microphon...                       0.0
# Intex Wired Gaming KB+MS (IT-KB334) Combo Set                            0.0
# Jabra PanaCast – Intelligent 180° Panoramic-4K ...                       0.0
# Keyboard                                                                 0.0
# Kindle Paperwhite (16 GB) – Now with a 6.8" dis...                       0.0
# Kindle Paperwhite Signature Edition Essentials ...                       0.0
# LEGO Marvel Infinity Gauntlet Set 76191, Collec...                       0.0
# Lenovo 00WG780 Enterprise Entry S3510 480GB SAT...                       0.0
# Lenovo D3-S4610 960 GB Solid State Drive - 2.5"...                       0.0
# Logitech C920x HD Pro Webcam, Full HD 1080p/30f...                       0.0
# Logitech G-Series Gaming Mouse                                           0.0
# Lowepro - Slingshot Edge 250 AW Camera Backpack...                       0.0
# Meta Quest 2 — Advanced All-In-One Virtual Real...                       0.0
# Microsoft Surface Pro 8 - 13" Touchscreen - Int...                       0.0
# Nike Air Max 270 React                                                   0.0
# Ninja SP101 Digital Air Fry Countertop Oven wit...                       0.0
# Nintendo Neon Purple/ Neon Orange Joy-Con (L-R)...                       0.0
# Oyen Digital Helix Dura 4TB USB-C (USB 3.2 Gen2...                       0.0
# PROGRACE Kids Camera Waterproof Boys - Toy Gift...                       0.0
# Playstation Sony 4, 500GB Slim System [CUH-2215...                       0.0
# Polaroid IS048 Digital Camera - Small Lightweig...                       0.0
# PowerA Enhanced Wireless Controller for Nintend...                       0.0
# Sample nameSpinBot Combo Pack Of BattleMods X1 ...                       0.0
# Sample nameTechGuy4u One Handed Gaming Keyboard...                       0.0
# Sample nameWoomzy Mini Hand Free Portable Neckb...                       0.0
# Samsung Galaxy S20 Ultra                                                 0.0
# SanDisk 64GB Ultra MicroSDXC UHS-I Memory Card ...                       0.0
# SanDisk Ultra 32GB Class 10 SDHC UHS-I Memory C...                       0.0
# Sanus VLF410B1 10-Inch Super Slim Full-Motion M...                       0.0
# Sony Compact Stereo Lavalier Microphone ECMLV1                           0.0
# Sony PlayStation 5 Console                                               1.0
# Sony Playstation 4 Pro White Version                                     0.0
# TP-Link Nano USB Wifi Dongle 150Mbps High Gain ...                       0.0
# Wacom Cintiq 16 Drawing Tablet with Full HD 15....                       0.0
# Wacom Intuos Small Graphics Drawing Tablet, inc...                       0.0
# amd Ryzen 5 5600G 3.9 GHz Upto 4.4 GHz AM4 Sock...                       0.0
# iPhone 11 Pro 256GB Memory                                               5.0
#
# user_id                                             63e7989616745843a0c18b76  \
# product
# AXE MEMORY Superb 512GB USB 3.1 SuperSpeed Flas...                       0.0
# Airpods Wireless Bluetooth Headphones                                    0.0
# Alfa Long-Range Dual-Band AC1200 Wireless USB 3...                       0.0
# Amazon Echo Dot 3rd Generation                                           0.0
# Apple 20W USB-C Power Adapter - iPhone Charger ...                       0.0
# Apple MagSafe Charger - Wireless Charger with F...                       0.0
# Apple iPad Pro                                                           0.0
# Beats by Dre Powerbeats Pro Wireless Earphones                           0.0
# Boytone - 2500W 2.1-Ch. Home Theater System - B...                       0.0
# Cannon EOS 80D DSLR Camera                                               5.0
# Canon EOS Rebel T7 DSLR Camera                                           0.0
# Canon EOS Rebel T7 DSLR Camera|2 Lens Kit with ...                       0.0
# DJI Air 2S, Drone Quadcopter UAV with 3-Axis Gi...                       0.0
# DJI Avata Explorer Combo - First-Person View Dr...                       0.0
# HP Reverb G2 VR Headset with Controller, Adjust...                       0.0
# HyperX Cloud II - Gaming Headset, 7.1 Surround ...                       0.0
# HyperX QuadCast S – RGB USB Condenser Microphon...                       0.0
# Intex Wired Gaming KB+MS (IT-KB334) Combo Set                            0.0
# Jabra PanaCast – Intelligent 180° Panoramic-4K ...                       0.0
# Keyboard                                                                 0.0
# Kindle Paperwhite (16 GB) – Now with a 6.8" dis...                       0.0
# Kindle Paperwhite Signature Edition Essentials ...                       0.0
# LEGO Marvel Infinity Gauntlet Set 76191, Collec...                       0.0
# Lenovo 00WG780 Enterprise Entry S3510 480GB SAT...                       0.0
# Lenovo D3-S4610 960 GB Solid State Drive - 2.5"...                       0.0
# Logitech C920x HD Pro Webcam, Full HD 1080p/30f...                       0.0
# Logitech G-Series Gaming Mouse                                           5.0
# Lowepro - Slingshot Edge 250 AW Camera Backpack...                       0.0
# Meta Quest 2 — Advanced All-In-One Virtual Real...                       0.0
# Microsoft Surface Pro 8 - 13" Touchscreen - Int...                       0.0
# Nike Air Max 270 React                                                   0.0
# Ninja SP101 Digital Air Fry Countertop Oven wit...                       0.0
# Nintendo Neon Purple/ Neon Orange Joy-Con (L-R)...                       0.0
# Oyen Digital Helix Dura 4TB USB-C (USB 3.2 Gen2...                       0.0
# PROGRACE Kids Camera Waterproof Boys - Toy Gift...                       0.0
# Playstation Sony 4, 500GB Slim System [CUH-2215...                       0.0
# Polaroid IS048 Digital Camera - Small Lightweig...                       0.0
# PowerA Enhanced Wireless Controller for Nintend...                       0.0
# Sample nameSpinBot Combo Pack Of BattleMods X1 ...                       0.0
# Sample nameTechGuy4u One Handed Gaming Keyboard...                       0.0
# Sample nameWoomzy Mini Hand Free Portable Neckb...                       0.0
# Samsung Galaxy S20 Ultra                                                 0.0
# SanDisk 64GB Ultra MicroSDXC UHS-I Memory Card ...                       0.0
# SanDisk Ultra 32GB Class 10 SDHC UHS-I Memory C...                       0.0
# Sanus VLF410B1 10-Inch Super Slim Full-Motion M...                       0.0
# Sony Compact Stereo Lavalier Microphone ECMLV1                           0.0
# Sony PlayStation 5 Console                                               0.0
# Sony Playstation 4 Pro White Version                                     0.0
# TP-Link Nano USB Wifi Dongle 150Mbps High Gain ...                       0.0
# Wacom Cintiq 16 Drawing Tablet with Full HD 15....                       0.0
# Wacom Intuos Small Graphics Drawing Tablet, inc...                       0.0
# amd Ryzen 5 5600G 3.9 GHz Upto 4.4 GHz AM4 Sock...                       0.0
# iPhone 11 Pro 256GB Memory                                               0.0
#
# user_id                                             63e7989616745843a0c18b77  \
# product
# AXE MEMORY Superb 512GB USB 3.1 SuperSpeed Flas...                       0.0
# Airpods Wireless Bluetooth Headphones                                    4.0
# Alfa Long-Range Dual-Band AC1200 Wireless USB 3...                       0.0
# Amazon Echo Dot 3rd Generation                                           0.0
# Apple 20W USB-C Power Adapter - iPhone Charger ...                       0.0
# Apple MagSafe Charger - Wireless Charger with F...                       0.0
# Apple iPad Pro                                                           4.0
# Beats by Dre Powerbeats Pro Wireless Earphones                           1.0
# Boytone - 2500W 2.1-Ch. Home Theater System - B...                       0.0
# Cannon EOS 80D DSLR Camera                                               0.0
# Canon EOS Rebel T7 DSLR Camera                                           4.0
# Canon EOS Rebel T7 DSLR Camera|2 Lens Kit with ...                       0.0
# DJI Air 2S, Drone Quadcopter UAV with 3-Axis Gi...                       0.0
# DJI Avata Explorer Combo - First-Person View Dr...                       0.0
# HP Reverb G2 VR Headset with Controller, Adjust...                       0.0
# HyperX Cloud II - Gaming Headset, 7.1 Surround ...                       0.0
# HyperX QuadCast S – RGB USB Condenser Microphon...                       0.0
# Intex Wired Gaming KB+MS (IT-KB334) Combo Set                            0.0
# Jabra PanaCast – Intelligent 180° Panoramic-4K ...                       0.0
# Keyboard                                                                 0.0
# Kindle Paperwhite (16 GB) – Now with a 6.8" dis...                       0.0
# Kindle Paperwhite Signature Edition Essentials ...                       0.0
# LEGO Marvel Infinity Gauntlet Set 76191, Collec...                       0.0
# Lenovo 00WG780 Enterprise Entry S3510 480GB SAT...                       0.0
# Lenovo D3-S4610 960 GB Solid State Drive - 2.5"...                       0.0
# Logitech C920x HD Pro Webcam, Full HD 1080p/30f...                       0.0
# Logitech G-Series Gaming Mouse                                           0.0
# Lowepro - Slingshot Edge 250 AW Camera Backpack...                       0.0
# Meta Quest 2 — Advanced All-In-One Virtual Real...                       0.0
# Microsoft Surface Pro 8 - 13" Touchscreen - Int...                       0.0
# Nike Air Max 270 React                                                   3.0
# Ninja SP101 Digital Air Fry Countertop Oven wit...                       0.0
# Nintendo Neon Purple/ Neon Orange Joy-Con (L-R)...                       0.0
# Oyen Digital Helix Dura 4TB USB-C (USB 3.2 Gen2...                       0.0
# PROGRACE Kids Camera Waterproof Boys - Toy Gift...                       0.0
# Playstation Sony 4, 500GB Slim System [CUH-2215...                       0.0
# Polaroid IS048 Digital Camera - Small Lightweig...                       0.0
# PowerA Enhanced Wireless Controller for Nintend...                       0.0
# Sample nameSpinBot Combo Pack Of BattleMods X1 ...                       0.0
# Sample nameTechGuy4u One Handed Gaming Keyboard...                       0.0
# Sample nameWoomzy Mini Hand Free Portable Neckb...                       0.0
# Samsung Galaxy S20 Ultra                                                 2.0
# SanDisk 64GB Ultra MicroSDXC UHS-I Memory Card ...                       0.0
# SanDisk Ultra 32GB Class 10 SDHC UHS-I Memory C...                       0.0
# Sanus VLF410B1 10-Inch Super Slim Full-Motion M...                       0.0
# Sony Compact Stereo Lavalier Microphone ECMLV1                           0.0
# Sony PlayStation 5 Console                                               2.0
# Sony Playstation 4 Pro White Version                                     0.0
# TP-Link Nano USB Wifi Dongle 150Mbps High Gain ...                       0.0
# Wacom Cintiq 16 Drawing Tablet with Full HD 15....                       0.0
# Wacom Intuos Small Graphics Drawing Tablet, inc...                       0.0
# amd Ryzen 5 5600G 3.9 GHz Upto 4.4 GHz AM4 Sock...                       0.0
# iPhone 11 Pro 256GB Memory                                               5.0
#
# user_id                                             63e7989616745843a0c18b78  \
# product
# AXE MEMORY Superb 512GB USB 3.1 SuperSpeed Flas...                       0.0
# Airpods Wireless Bluetooth Headphones                                    0.0
# Alfa Long-Range Dual-Band AC1200 Wireless USB 3...                       0.0
# Amazon Echo Dot 3rd Generation                                           5.0
# Apple 20W USB-C Power Adapter - iPhone Charger ...                       0.0
# Apple MagSafe Charger - Wireless Charger with F...                       0.0
# Apple iPad Pro                                                           0.0
# Beats by Dre Powerbeats Pro Wireless Earphones                           0.0
# Boytone - 2500W 2.1-Ch. Home Theater System - B...                       0.0
# Cannon EOS 80D DSLR Camera                                               0.0
# Canon EOS Rebel T7 DSLR Camera                                           0.0
# Canon EOS Rebel T7 DSLR Camera|2 Lens Kit with ...                       0.0
# DJI Air 2S, Drone Quadcopter UAV with 3-Axis Gi...                       0.0
# DJI Avata Explorer Combo - First-Person View Dr...                       0.0
# HP Reverb G2 VR Headset with Controller, Adjust...                       0.0
# HyperX Cloud II - Gaming Headset, 7.1 Surround ...                       0.0
# HyperX QuadCast S – RGB USB Condenser Microphon...                       0.0
# Intex Wired Gaming KB+MS (IT-KB334) Combo Set                            0.0
# Jabra PanaCast – Intelligent 180° Panoramic-4K ...                       0.0
# Keyboard                                                                 0.0
# Kindle Paperwhite (16 GB) – Now with a 6.8" dis...                       0.0
# Kindle Paperwhite Signature Edition Essentials ...                       0.0
# LEGO Marvel Infinity Gauntlet Set 76191, Collec...                       0.0
# Lenovo 00WG780 Enterprise Entry S3510 480GB SAT...                       0.0
# Lenovo D3-S4610 960 GB Solid State Drive - 2.5"...                       0.0
# Logitech C920x HD Pro Webcam, Full HD 1080p/30f...                       0.0
# Logitech G-Series Gaming Mouse                                           0.0
# Lowepro - Slingshot Edge 250 AW Camera Backpack...                       0.0
# Meta Quest 2 — Advanced All-In-One Virtual Real...                       0.0
# Microsoft Surface Pro 8 - 13" Touchscreen - Int...                       0.0
# Nike Air Max 270 React                                                   0.0
# Ninja SP101 Digital Air Fry Countertop Oven wit...                       0.0
# Nintendo Neon Purple/ Neon Orange Joy-Con (L-R)...                       0.0
# Oyen Digital Helix Dura 4TB USB-C (USB 3.2 Gen2...                       0.0
# PROGRACE Kids Camera Waterproof Boys - Toy Gift...                       0.0
# Playstation Sony 4, 500GB Slim System [CUH-2215...                       0.0
# Polaroid IS048 Digital Camera - Small Lightweig...                       0.0
# PowerA Enhanced Wireless Controller for Nintend...                       0.0
# Sample nameSpinBot Combo Pack Of BattleMods X1 ...                       0.0
# Sample nameTechGuy4u One Handed Gaming Keyboard...                       0.0
# Sample nameWoomzy Mini Hand Free Portable Neckb...                       0.0
# Samsung Galaxy S20 Ultra                                                 3.0
# SanDisk 64GB Ultra MicroSDXC UHS-I Memory Card ...                       0.0
# SanDisk Ultra 32GB Class 10 SDHC UHS-I Memory C...                       0.0
# Sanus VLF410B1 10-Inch Super Slim Full-Motion M...                       0.0
# Sony Compact Stereo Lavalier Microphone ECMLV1                           0.0
# Sony PlayStation 5 Console                                               0.0
# Sony Playstation 4 Pro White Version                                     0.0
# TP-Link Nano USB Wifi Dongle 150Mbps High Gain ...                       0.0
# Wacom Cintiq 16 Drawing Tablet with Full HD 15....                       0.0
# Wacom Intuos Small Graphics Drawing Tablet, inc...                       0.0
# amd Ryzen 5 5600G 3.9 GHz Upto 4.4 GHz AM4 Sock...                       0.0
# iPhone 11 Pro 256GB Memory                                               0.0
#
# user_id                                             ...  \
# product                                             ...
# AXE MEMORY Superb 512GB USB 3.1 SuperSpeed Flas...  ...
# Airpods Wireless Bluetooth Headphones               ...
# Alfa Long-Range Dual-Band AC1200 Wireless USB 3...  ...
# Amazon Echo Dot 3rd Generation                      ...
# Apple 20W USB-C Power Adapter - iPhone Charger ...  ...
# Apple MagSafe Charger - Wireless Charger with F...  ...
# Apple iPad Pro                                      ...
# Beats by Dre Powerbeats Pro Wireless Earphones      ...
# Boytone - 2500W 2.1-Ch. Home Theater System - B...  ...
# Cannon EOS 80D DSLR Camera                          ...
# Canon EOS Rebel T7 DSLR Camera                      ...
# Canon EOS Rebel T7 DSLR Camera|2 Lens Kit with ...  ...
# DJI Air 2S, Drone Quadcopter UAV with 3-Axis Gi...  ...
# DJI Avata Explorer Combo - First-Person View Dr...  ...
# HP Reverb G2 VR Headset with Controller, Adjust...  ...
# HyperX Cloud II - Gaming Headset, 7.1 Surround ...  ...
# HyperX QuadCast S – RGB USB Condenser Microphon...  ...
# Intex Wired Gaming KB+MS (IT-KB334) Combo Set       ...
# Jabra PanaCast – Intelligent 180° Panoramic-4K ...  ...
# Keyboard                                            ...
# Kindle Paperwhite (16 GB) – Now with a 6.8" dis...  ...
# Kindle Paperwhite Signature Edition Essentials ...  ...
# LEGO Marvel Infinity Gauntlet Set 76191, Collec...  ...
# Lenovo 00WG780 Enterprise Entry S3510 480GB SAT...  ...
# Lenovo D3-S4610 960 GB Solid State Drive - 2.5"...  ...
# Logitech C920x HD Pro Webcam, Full HD 1080p/30f...  ...
# Logitech G-Series Gaming Mouse                      ...
# Lowepro - Slingshot Edge 250 AW Camera Backpack...  ...
# Meta Quest 2 — Advanced All-In-One Virtual Real...  ...
# Microsoft Surface Pro 8 - 13" Touchscreen - Int...  ...
# Nike Air Max 270 React                              ...
# Ninja SP101 Digital Air Fry Countertop Oven wit...  ...
# Nintendo Neon Purple/ Neon Orange Joy-Con (L-R)...  ...
# Oyen Digital Helix Dura 4TB USB-C (USB 3.2 Gen2...  ...
# PROGRACE Kids Camera Waterproof Boys - Toy Gift...  ...
# Playstation Sony 4, 500GB Slim System [CUH-2215...  ...
# Polaroid IS048 Digital Camera - Small Lightweig...  ...
# PowerA Enhanced Wireless Controller for Nintend...  ...
# Sample nameSpinBot Combo Pack Of BattleMods X1 ...  ...
# Sample nameTechGuy4u One Handed Gaming Keyboard...  ...
# Sample nameWoomzy Mini Hand Free Portable Neckb...  ...
# Samsung Galaxy S20 Ultra                            ...
# SanDisk 64GB Ultra MicroSDXC UHS-I Memory Card ...  ...
# SanDisk Ultra 32GB Class 10 SDHC UHS-I Memory C...  ...
# Sanus VLF410B1 10-Inch Super Slim Full-Motion M...  ...
# Sony Compact Stereo Lavalier Microphone ECMLV1      ...
# Sony PlayStation 5 Console                          ...
# Sony Playstation 4 Pro White Version                ...
# TP-Link Nano USB Wifi Dongle 150Mbps High Gain ...  ...
# Wacom Cintiq 16 Drawing Tablet with Full HD 15....  ...
# Wacom Intuos Small Graphics Drawing Tablet, inc...  ...
# amd Ryzen 5 5600G 3.9 GHz Upto 4.4 GHz AM4 Sock...  ...
# iPhone 11 Pro 256GB Memory                          ...
#
# user_id                                             644a5db34d690900314fa784  \
# product
# AXE MEMORY Superb 512GB USB 3.1 SuperSpeed Flas...                       0.0
# Airpods Wireless Bluetooth Headphones                                    0.0
# Alfa Long-Range Dual-Band AC1200 Wireless USB 3...                       0.0
# Amazon Echo Dot 3rd Generation                                           3.0
# Apple 20W USB-C Power Adapter - iPhone Charger ...                       0.0
# Apple MagSafe Charger - Wireless Charger with F...                       0.0
# Apple iPad Pro                                                           0.0
# ...
# Jabra PanaCast – Intelligent 180° Panoramic-4K ...                       0.0
# Keyboard                                                                 3.0
# Kindle Paperwhite (16 GB) – Now with a 6.8" dis...                       4.0
# Kindle Paperwhite Signature Edition Essentials ...                       0.0
# LEGO Marvel Infinity Gauntlet Set 76191, Collec...                       4.0
# Lenovo 00WG780 Enterprise Entry S3510 480GB SAT...                       0.0
# Lenovo D3-S4610 960 GB Solid State Drive - 2.5"...                       3.0
# Logitech C920x HD Pro Webcam, Full HD 1080p/30f...                       2.0
# Logitech G-Series Gaming Mouse                                           4.0
# Lowepro - Slingshot Edge 250 AW Camera Backpack...                       3.0
# Meta Quest 2 — Advanced All-In-One Virtual Real...                       4.0
# Microsoft Surface Pro 8 - 13" Touchscreen - Int...                       4.0
# Nike Air Max 270 React                                                   0.0
# Ninja SP101 Digital Air Fry Countertop Oven wit...                       0.0
# Nintendo Neon Purple/ Neon Orange Joy-Con (L-R)...                       0.0
# Oyen Digital Helix Dura 4TB USB-C (USB 3.2 Gen2...                       0.0
# PROGRACE Kids Camera Waterproof Boys - Toy Gift...                       0.0
# Playstation Sony 4, 500GB Slim System [CUH-2215...                       0.0
# Polaroid IS048 Digital Camera - Small Lightweig...                       3.0
# PowerA Enhanced Wireless Controller for Nintend...                       4.0
# Sample nameSpinBot Combo Pack Of BattleMods X1 ...                       3.0
# Sample nameTechGuy4u One Handed Gaming Keyboard...                       0.0
# Sample nameWoomzy Mini Hand Free Portable Neckb...                       4.0
# Samsung Galaxy S20 Ultra                                                 0.0
# SanDisk 64GB Ultra MicroSDXC UHS-I Memory Card ...                       4.0
# SanDisk Ultra 32GB Class 10 SDHC UHS-I Memory C...                       0.0
# Sanus VLF410B1 10-Inch Super Slim Full-Motion M...                       4.0
# Sony Compact Stereo Lavalier Microphone ECMLV1                           0.0
# Sony PlayStation 5 Console                                               0.0
# Sony Playstation 4 Pro White Version                                     0.0
# TP-Link Nano USB Wifi Dongle 150Mbps High Gain ...                       3.0
# Wacom Cintiq 16 Drawing Tablet with Full HD 15....                       0.0
# Wacom Intuos Small Graphics Drawing Tablet, inc...                       3.0
# amd Ryzen 5 5600G 3.9 GHz Upto 4.4 GHz AM4 Sock...                       0.0
# iPhone 11 Pro 256GB Memory                                               0.0
#
# user_id                                             64597748e640040030448168  \
# product
# AXE MEMORY Superb 512GB USB 3.1 SuperSpeed Flas...                       0.0
# Airpods Wireless Bluetooth Headphones                                    0.0
# Alfa Long-Range Dual-Band AC1200 Wireless USB 3...                       5.0
# Amazon Echo Dot 3rd Generation                                           0.0
# Apple 20W USB-C Power Adapter - iPhone Charger ...                       4.0
# Apple MagSafe Charger - Wireless Charger with F...                       0.0
# Apple iPad Pro                                                           0.0
# Beats by Dre Powerbeats Pro Wireless Earphones                           0.0
# Boytone - 2500W 2.1-Ch. Home Theater System - B...                       4.0
# Cannon EOS 80D DSLR Camera                                               0.0
# Canon EOS Rebel T7 DSLR Camera                                           0.0
# Canon EOS Rebel T7 DSLR Camera|2 Lens Kit with ...                       4.0
# DJI Air 2S, Drone Quadcopter UAV with 3-Axis Gi...                       0.0
# DJI Avata Explorer Combo - First-Person View Dr...                       4.0
# HP Reverb G2 VR Headset with Controller, Adjust...                       3.0
# HyperX Cloud II - Gaming Headset, 7.1 Surround ...                       5.0
# HyperX QuadCast S – RGB USB Condenser Microphon...                       0.0
# Intex Wired Gaming KB+MS (IT-KB334) Combo Set                            4.0
# Jabra PanaCast – Intelligent 180° Panoramic-4K ...                       5.0
# Keyboard                                                                 0.0
# Kindle Paperwhite (16 GB) – Now with a 6.8" dis...                       0.0
# Kindle Paperwhite Signature Edition Essentials ...                       4.0
# LEGO Marvel Infinity Gauntlet Set 76191, Collec...                       0.0
# Lenovo 00WG780 Enterprise Entry S3510 480GB SAT...                       4.0
# Lenovo D3-S4610 960 GB Solid State Drive - 2.5"...                       0.0
# Logitech C920x HD Pro Webcam, Full HD 1080p/30f...                       0.0
# Logitech G-Series Gaming Mouse                                           0.0
# Lowepro - Slingshot Edge 250 AW Camera Backpack...                       0.0
# Meta Quest 2 — Advanced All-In-One Virtual Real...                       0.0
# Microsoft Surface Pro 8 - 13" Touchscreen - Int...                       0.0
# Nike Air Max 270 React                                                   5.0
# Ninja SP101 Digital Air Fry Countertop Oven wit...                       4.0
# Nintendo Neon Purple/ Neon Orange Joy-Con (L-R)...                       5.0
# Oyen Digital Helix Dura 4TB USB-C (USB 3.2 Gen2...                       5.0
# PROGRACE Kids Camera Waterproof Boys - Toy Gift...                       4.0
# Playstation Sony 4, 500GB Slim System [CUH-2215...                       0.0
# Polaroid IS048 Digital Camera - Small Lightweig...                       0.0
# PowerA Enhanced Wireless Controller for Nintend...                       0.0
# Sample nameSpinBot Combo Pack Of BattleMods X1 ...                       0.0
# Sample nameTechGuy4u One Handed Gaming Keyboard...                       4.0
# Sample nameWoomzy Mini Hand Free Portable Neckb...                       0.0
# Samsung Galaxy S20 Ultra                                                 0.0
# SanDisk 64GB Ultra MicroSDXC UHS-I Memory Card ...                       0.0
# SanDisk Ultra 32GB Class 10 SDHC UHS-I Memory C...                       4.0
# Sanus VLF410B1 10-Inch Super Slim Full-Motion M...                       0.0
# Sony Compact Stereo Lavalier Microphone ECMLV1                           4.0
# Sony PlayStation 5 Console                                               0.0
# Sony Playstation 4 Pro White Version                                     0.0
# TP-Link Nano USB Wifi Dongle 150Mbps High Gain ...                       0.0
# Wacom Cintiq 16 Drawing Tablet with Full HD 15....                       5.0
# Wacom Intuos Small Graphics Drawing Tablet, inc...                       0.0
# amd Ryzen 5 5600G 3.9 GHz Upto 4.4 GHz AM4 Sock...                       0.0
# iPhone 11 Pro 256GB Memory                                               0.0
#
# user_id                                             645978e5e640040030448235  \
# product
# AXE MEMORY Superb 512GB USB 3.1 SuperSpeed Flas...                       3.0
# Airpods Wireless Bluetooth Headphones                                    0.0
# Alfa Long-Range Dual-Band AC1200 Wireless USB 3...                       2.0
# Amazon Echo Dot 3rd Generation                                           3.0
# Apple 20W USB-C Power Adapter - iPhone Charger ...                       4.0
# Apple MagSafe Charger - Wireless Charger with F...                       2.0
# Apple iPad Pro                                                           0.0
# Beats by Dre Powerbeats Pro Wireless Earphones                           0.0
# Boytone - 2500W 2.1-Ch. Home Theater System - B...                       4.0
# Cannon EOS 80D DSLR Camera                                               4.0
# Canon EOS Rebel T7 DSLR Camera                                           0.0
# Canon EOS Rebel T7 DSLR Camera|2 Lens Kit with ...                       4.0
# DJI Air 2S, Drone Quadcopter UAV with 3-Axis Gi...                       0.0
# DJI Avata Explorer Combo - First-Person View Dr...                       4.0
# HP Reverb G2 VR Headset with Controller, Adjust...                       4.0
# HyperX Cloud II - Gaming Headset, 7.1 Surround ...                       0.0
# HyperX QuadCast S – RGB USB Condenser Microphon...                       3.0
# Intex Wired Gaming KB+MS (IT-KB334) Combo Set                            0.0
# Jabra PanaCast – Intelligent 180° Panoramic-4K ...                       4.0
# Keyboard                                                                 0.0
# Kindle Paperwhite (16 GB) – Now with a 6.8" dis...                       0.0
# Kindle Paperwhite Signature Edition Essentials ...                       5.0
# LEGO Marvel Infinity Gauntlet Set 76191, Collec...                       4.0
# Lenovo 00WG780 Enterprise Entry S3510 480GB SAT...                       4.0
# Lenovo D3-S4610 960 GB Solid State Drive - 2.5"...                       3.0
# Logitech C920x HD Pro Webcam, Full HD 1080p/30f...                       5.0
# Logitech G-Series Gaming Mouse                                           0.0
# Lowepro - Slingshot Edge 250 AW Camera Backpack...                       0.0
# Meta Quest 2 — Advanced All-In-One Virtual Real...                       0.0
# Microsoft Surface Pro 8 - 13" Touchscreen - Int...                       3.0
# Nike Air Max 270 React                                                   0.0
# Ninja SP101 Digital Air Fry Countertop Oven wit...                       4.0
# Nintendo Neon Purple/ Neon Orange Joy-Con (L-R)...                       3.0
# Oyen Digital Helix Dura 4TB USB-C (USB 3.2 Gen2...                       2.0
# PROGRACE Kids Camera Waterproof Boys - Toy Gift...                       2.0
# Playstation Sony 4, 500GB Slim System [CUH-2215...                       0.0
# Polaroid IS048 Digital Camera - Small Lightweig...                       5.0
# PowerA Enhanced Wireless Controller for Nintend...                       2.0
# Sample nameSpinBot Combo Pack Of BattleMods X1 ...                       4.0
# Sample nameTechGuy4u One Handed Gaming Keyboard...                       0.0
# Sample nameWoomzy Mini Hand Free Portable Neckb...                       0.0
# Samsung Galaxy S20 Ultra                                                 0.0
# SanDisk 64GB Ultra MicroSDXC UHS-I Memory Card ...                       4.0
# SanDisk Ultra 32GB Class 10 SDHC UHS-I Memory C...                       3.0
# Sanus VLF410B1 10-Inch Super Slim Full-Motion M...                       0.0
# Sony Compact Stereo Lavalier Microphone ECMLV1                           3.0
# Sony PlayStation 5 Console                                               0.0
# Sony Playstation 4 Pro White Version                                     4.0
# TP-Link Nano USB Wifi Dongle 150Mbps High Gain ...                       5.0
# Wacom Cintiq 16 Drawing Tablet with Full HD 15....                       0.0
# Wacom Intuos Small Graphics Drawing Tablet, inc...                       3.0
# amd Ryzen 5 5600G 3.9 GHz Upto 4.4 GHz AM4 Sock...                       0.0
# iPhone 11 Pro 256GB Memory                                               4.0
#
# user_id                                             64598b04138df50030b79610
# product
# AXE MEMORY Superb 512GB USB 3.1 SuperSpeed Flas...                       5.0
# Airpods Wireless Bluetooth Headphones                                    0.0
# Alfa Long-Range Dual-Band AC1200 Wireless USB 3...                       1.0
# Amazon Echo Dot 3rd Generation                                           0.0
# Apple 20W USB-C Power Adapter - iPhone Charger ...                       1.0
# Apple MagSafe Charger - Wireless Charger with F...                       3.0
# Apple iPad Pro                                                           0.0
# Beats by Dre Powerbeats Pro Wireless Earphones                           0.0
# Boytone - 2500W 2.1-Ch. Home Theater System - B...                       0.0
# Cannon EOS 80D DSLR Camera                                               0.0
# Canon EOS Rebel T7 DSLR Camera                                           0.0
# Canon EOS Rebel T7 DSLR Camera|2 Lens Kit with ...                       1.0
# DJI Air 2S, Drone Quadcopter UAV with 3-Axis Gi...                       3.0
# DJI Avata Explorer Combo - First-Person View Dr...                       2.0
# HP Reverb G2 VR Headset with Controller, Adjust...                       0.0
# HyperX Cloud II - Gaming Headset, 7.1 Surround ...                       0.0
# HyperX QuadCast S – RGB USB Condenser Microphon...                       4.0
# Intex Wired Gaming KB+MS (IT-KB334) Combo Set                            0.0
# Jabra PanaCast – Intelligent 180° Panoramic-4K ...                       1.0
# Keyboard                                                                 0.0
# Kindle Paperwhite (16 GB) – Now with a 6.8" dis...                       2.0
# Kindle Paperwhite Signature Edition Essentials ...                       3.0
# LEGO Marvel Infinity Gauntlet Set 76191, Collec...                       0.0
# Lenovo 00WG780 Enterprise Entry S3510 480GB SAT...                       2.0
# Lenovo D3-S4610 960 GB Solid State Drive - 2.5"...                       4.0
# Logitech C920x HD Pro Webcam, Full HD 1080p/30f...                       3.0
# Logitech G-Series Gaming Mouse                                           0.0
# Lowepro - Slingshot Edge 250 AW Camera Backpack...                       0.0
# Meta Quest 2 — Advanced All-In-One Virtual Real...                       2.0
# Microsoft Surface Pro 8 - 13" Touchscreen - Int...                       0.0
# Nike Air Max 270 React                                                   0.0
# Ninja SP101 Digital Air Fry Countertop Oven wit...                       2.0
# Nintendo Neon Purple/ Neon Orange Joy-Con (L-R)...                       4.0
# Oyen Digital Helix Dura 4TB USB-C (USB 3.2 Gen2...                       4.0
# PROGRACE Kids Camera Waterproof Boys - Toy Gift...                       3.0
# Playstation Sony 4, 500GB Slim System [CUH-2215...                       0.0
# Polaroid IS048 Digital Camera - Small Lightweig...                       4.0
# PowerA Enhanced Wireless Controller for Nintend...                       5.0
# Sample nameSpinBot Combo Pack Of BattleMods X1 ...                       0.0
# Sample nameTechGuy4u One Handed Gaming Keyboard...                       0.0
# Sample nameWoomzy Mini Hand Free Portable Neckb...                       0.0
# Samsung Galaxy S20 Ultra                                                 0.0
# SanDisk 64GB Ultra MicroSDXC UHS-I Memory Card ...                       5.0
# SanDisk Ultra 32GB Class 10 SDHC UHS-I Memory C...                       5.0
# Sanus VLF410B1 10-Inch Super Slim Full-Motion M...                       0.0
# Sony Compact Stereo Lavalier Microphone ECMLV1                           3.0
# Sony PlayStation 5 Console                                               0.0
# Sony Playstation 4 Pro White Version                                     0.0
# TP-Link Nano USB Wifi Dongle 150Mbps High Gain ...                       1.0
# Wacom Cintiq 16 Drawing Tablet with Full HD 15....                       3.0
# Wacom Intuos Small Graphics Drawing Tablet, inc...                       0.0
# amd Ryzen 5 5600G 3.9 GHz Upto 4.4 GHz AM4 Sock...                       0.0
# iPhone 11 Pro 256GB Memory                                               0.0
#
# [53 rows x 26 columns]

# %% [markdown]
# ## Calculating Similarity Scores

# %% [markdown]
# To calculate similarity scores between products based on user ratings, you can use the `cosine_similarity` function from the `sklearn.metrics.pairwise` module.

# %%
from sklearn.metrics.pairwise import cosine_similarity

# %%
similarity_score=cosine_similarity(userRating)

# %%
similarity_score
# Out:
# array([[1.        , 0.        , 0.26146048, ..., 0.75164603, 0.16570343,
#         0.11877696],
#        [0.        , 1.        , 0.        , ..., 0.        , 0.07276069,
#         0.55414883],
#        [0.26146048, 0.        , 1.        , ..., 0.21081851, 0.        ,
#         0.11104687],
#        ...,
#        [0.75164603, 0.        , 0.21081851, ..., 1.        , 0.24494897,
#         0.17558051],
#        [0.16570343, 0.07276069, 0.        , ..., 0.24494897, 1.        ,
#         0.        ],
#        [0.11877696, 0.55414883, 0.11104687, ..., 0.17558051, 0.        ,
#         1.        ]])

# %% [markdown]
# ## Generating Recommendations

# %% [markdown]
# With the similarity scores calculated, you can now generate product `recommendations` based on a given product. The recommended function takes a product name as input and returns a list of similar products based on the highest similarity scores.

# %%
def recommended(book_name):
    #index fetch 
    index=np.where(userRating.index==book_name)[0][0]
    similar_items=sorted(list(enumerate(similarity_score[index])),key=lambda x:x[1],reverse=True)[1:4]
    data = []
    for i in similar_items:
        item = []
        temp_df = df[df['product'] == userRating.index[i[0]]]
        item.extend(list(temp_df.drop_duplicates('product')['product'].values))
        item.extend(list(temp_df.drop_duplicates('product')['rating'].values))
        item.extend(list(temp_df.drop_duplicates('product')['product_id'].values))
        item.extend(list(temp_df.drop_duplicates('product')['image'].values))
        item.extend(list(temp_df.drop_duplicates('product')['price'].values))
        data.append(item)
    return data

# %%
recommended("iPhone 11 Pro 256GB Memory")
# Out:
# [['Airpods Wireless Bluetooth Headphones',
#   5,
#   ObjectId('63e7989616745843a0c18b7c'),
#   '/images/airpods.jpg',
#   89.99],
#  ['Sony PlayStation 5 Console',
#   1,
#   ObjectId('63e7989616745843a0c18b8d'),
#   '/images/istockphoto-1287493837-612x612.jpg',
#   499.99],
#  ['Sony Playstation 4 Pro White Version',
#   4,
#   ObjectId('63e7989616745843a0c18b7f'),
#   '/images/playstation.jpg',
#   399.99]]

# %%
userRating.index[5]
# Out:
# 'Apple MagSafe Charger - Wireless Charger with Fast Charging Capability, Type C Wall Charger, Compatible with iPhone and AirPods'

# %% [markdown]
# ## Saving Data for web Recommendation

# %% [markdown]
# If you intend to use the generated user ratings, DataFrame, and similarity scores for web recommendation purposes, you can save them as pickle files.

# %%
import pickle
pickle.dump(userRating,open('WebReco/userRating.pkl','wb'))
pickle.dump(df,open('WebReco/df.pkl','wb'))
pickle.dump(similarity_score,open('WebReco/similarity_score.pkl','wb'))
